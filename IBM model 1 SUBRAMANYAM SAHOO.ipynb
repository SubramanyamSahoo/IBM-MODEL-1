# %% [markdown]
# # IBM model 1 by SUBRAMANYAM SAHOO

# %%
import numpy as np
import pandas as pd
import math
from nltk.tokenize import word_tokenize
from collections import defaultdict
from nltk.translate.metrics import alignment_error_rate
from nltk.metrics.scores import (precision, recall)
from operator import itemgetter
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#DATA
file = open('./train.en', 'r', encoding="utf8")
train_en = file.read()
raw_sentences_train_en = train_en.split("\n")

file = open('./train.hi', 'r', encoding="utf8")
train_hi = file.read()
raw_sentences_train_hi = train_hi.split("\n")

file = open('./test.en', 'r', encoding="utf8")
test_en = file.read()
raw_sentences_test_en = test_en.split("\n")

file = open('./test.hi', 'r', encoding="utf8")
test_hi = file.read()
raw_sentences_test_hi = test_hi.split("\n")

file = open('./dev.en.txt', 'r', encoding="utf8")
dev_en = file.read()
raw_sentences_dev_en = dev_en.split("\n")

file = open('./dev.hi', 'r', encoding="utf8")
dev_hi = file.read()
raw_sentences_dev_hi = dev_hi.split("\n")

# %%
def add_null(data):
    list_ = []
    for sentence in data:
        list_.append("NULL " + sentence)
#     print(list_[2])
    return list_

# %%
sentences_dev_hi = add_null(raw_sentences_dev_hi)
sentences_test_hi = add_null(raw_sentences_test_hi)
sentences_train_hi = add_null(raw_sentences_train_hi)

# %%
def make_lower_case(data):
    list_ = []
    for sentence in data:
        list_.append("NULL " + sentence.lower())
#     print(list_[2])
    return list_

# %%
sentences_dev_en = make_lower_case(raw_sentences_dev_en)
sentences_test_en = make_lower_case(raw_sentences_test_en)
sentences_train_en = make_lower_case(raw_sentences_train_en)

# %%
def is_converged(new, old, epoch):
    epsilone = 0.00000001
#     new = list(new.values())
#     old = list(old.values())
    
#     new_val = []
#     for (hin, ddict) in new.items():
#         for (eng, prob) in ddict.items():
#             new_val.append('{0:.8f}'.format(prob))
            
#     old_val = []
#     for (hin, ddict) in old.items():
#         for (eng, prob) in ddict.items():
#             old_val.append('{0:.8f}'.format(prob))        

#     for i in range(len(old_val)):
#         if math.fabs(float(new_val[i]) - float(old_val[i])) > epsilone: 
    if epoch < 15:
        return False
    return True

# %%
def perform_EM(en_sentences, hi_sentences):
    
    uni_ini = 0.00001
    
    translation_prob = defaultdict(lambda: float(uni_ini))
    translation_prob_prev = defaultdict(float)
    
    epoch = 0
    
    while True:

        epoch += 1
        print("epoch num:", epoch,"\n")
        count = defaultdict(float)
        total = defaultdict(float)
        s_total = defaultdict(float)
        
        for index_sen, hin_sen in enumerate(hi_sentences):
            #compute normalization
            hin_sen_words = hin_sen.split(" ")
            for hin_word in hin_sen_words:
                s_total[hin_word] = 0
                eng_sen_words = en_sentences[index_sen].split(" ")
                for eng_word in eng_sen_words:
                        s_total[hin_word] += translation_prob[(hin_word, eng_word)]
            
            #collect counts
            for hin_word in hin_sen_words:
                eng_sen_words = en_sentences[index_sen].split(" ")
                for eng_word in eng_sen_words:
                        count[(hin_word, eng_word)] += translation_prob[(hin_word, eng_word)]/s_total[hin_word]
                        total[eng_word] += translation_prob[(hin_word, eng_word)]/s_total[hin_word]                   

        #estimate probabilities
        for (hin_word, eng_word) in translation_prob.keys():
                translation_prob[(hin_word, eng_word)] = count[(hin_word, eng_word)]/total[eng_word]

        if is_converged(translation_prob, translation_prob_prev, epoch) == True:
            break
        
        translation_prob_prev = translation_prob
        
        
    return translation_prob

# %%
def train_model(sentences_train_en, sentences_train_hi):
    
    translation_prob = perform_EM(sentences_train_en, sentences_train_hi)
    return translation_prob

# %%
tef = train_model(sentences_train_en, sentences_train_hi)
# Out:
# epoch num: 1
#
# epoch num: 2
#
# epoch num: 3
#
# epoch num: 4
#
# epoch num: 5
#
# epoch num: 6
#
# epoch num: 7
#
# epoch num: 8
#
# epoch num: 9
#
# epoch num: 10
#
# epoch num: 11
#
# epoch num: 12
#
# epoch num: 13
#
# epoch num: 14
#
# epoch num: 15

# %%
iterations = 0
for ((e_word, hin_word), value) in sorted(tef.items(), key=itemgetter(1), reverse=True):
    if iterations < 200:
        print("{:<20}{:>20.2}".format("P(%s|%s)" %(e_word, hin_word), value))
    else:
        break
    iterations += 1
# Out:
# P(तक|till)                           1.0
# P(शरीर|body)                        0.99
# P(तनाव|tension)                     0.99
# P(,|,)                              0.99
# P(सेरीब्रम|cerebrum)                0.99
# P(पेट|stomach)                      0.99
# P(15|15)                            0.99
# P(या|or)                            0.98
# P(कैंसर|cancer)                     0.98
# P(कम|less)                          0.98
# P(स्तर|level)                       0.98
# P(मस्तिष्क|brain)                   0.98
# P(मानसिक|mental)                    0.97
# P(ग्राम|grams)                      0.97
# P(भारत|india)                       0.97
# P(आधार|basis)                       0.97
# P(संक्रमित|infected)                0.97
# P(दो|two)                           0.97
# P(पानी|water)                       0.96
# P(भी|also)                          0.96
# P(उपलब्ध|available)                 0.96
# P(नमक|salt)                         0.96
# P(नाम|name)                         0.96
# P(शारीरिक|physical)                 0.95
# P(3|3)                              0.95
# P(सरसों|mustard)                    0.95
# P(हर्निया|hernia)                   0.94
# P(प्रभावित|affected)                0.94
# P(आर्थराइटिस|arthritis)                0.94
# P(जन्म|birth)                       0.94
# P(व्यक्ति|person)                   0.94
# P(कंप्यूटर|computer)                0.94
# P(हाथ|hand)                         0.94
# P(20|20)                            0.93
# P(बुद्धि|intelligence)                0.93
# P(पर|on)                            0.93
# P(2|2)                              0.93
# P(देश|country)                      0.93
# P(युक्त|containing)                 0.93
# P(थर्मोग्राफी|thermography)                0.93
# P(आज|today)                         0.93
# P(से|from)                          0.93
# P(कुछ|some)                         0.92
# P(मिनट|minutes)                     0.92
# P(गाँठ|knot)                        0.92
# P(देहरादून|dehradun)                0.92
# P(सिर|head)                         0.91
# P(कम|least)                         0.91
# P(में|in)                           0.91
# P(बजाय|instead)                     0.91
# P(दर|rate)                          0.91
# P(डायबिटीज|diabetes)                0.91
# P(नियंत्रण|control)                 0.91
# P(कैलोरी|calories)                  0.91
# P(दर्द|pain)                        0.91
# P(हेपेटाइटिस-ए|hepatitis-a)                 0.9
# P(मृत्यु|death)                      0.9
# P(बीन्स|beans)                       0.9
# P(गाँठ|tumor)                        0.9
# P(पोलियो|polio)                     0.89
# P(शहद|honey)                        0.89
# P(ग्रामीण|rural)                    0.89
# P(कारण|reason)                      0.89
# P(कंप्यूटर|computers)                0.89
# P(45|45)                            0.88
# P(प्रजनन|reproduction)                0.88
# P(सेवन|consumption)                 0.88
# P(स्वास्थ्य|health)                 0.88
# P(40|40)                            0.88
# P(उत्तराखण्ड|uttarakhand)                0.88
# P(गर्भवती|pregnant)                 0.88
# P(12|12)                            0.88
# P(समय|time)                         0.87
# P(भी|too)                           0.87
# P(मात्रा|quantity)                  0.87
# P(स्तन|breast)                      0.87
# P(इलायची|cardamom)                  0.87
# P(अब|now)                           0.87
# P(शक्ति|power)                      0.87
# P(सुरक्षित|safe)                    0.87
# P(रेकी|reiki)                       0.86
# P(क्षमता|capacity)                  0.86
# P(त्वचा|skin)                       0.86
# P(संक्रमण|contraction)                0.86
# P(तेल|oil)                          0.86
# P(दिन|day)                          0.85
# P(कैलोरी|calorie)                   0.85
# P(दोनों|both)                       0.85
# P(सेब|apple)                        0.85
# P(विशेष|special)                    0.84
# P(समस्या|problem)                   0.84
# P(विटामिन|vitamin)                  0.84
# P(वजन|weight)                       0.84
# P(सूजन|swelling)                    0.84
# P(आदि|etc)                          0.83
# P(बिना|without)                     0.83
# P(आँखों|eyes)                       0.83
# P(पेशाब|urination)                  0.83
# P(विद्यार्थी|student)                0.83
# P(सामान्य|normal)                   0.83
# P(सलाह|advice)                      0.83
# P(नियोजन|planning)                  0.83
# P(मैमोग्राफी|mammography)                0.83
# P(टीका|vaccine)                     0.83
# P(प्रतिशत|percent)                  0.83
# P(क्षेत्र|area)                     0.82
# P(1|1)                              0.82
# P(भाषा|language)                    0.82
# P(मोतियाबिंद|cataract)                0.82
# P(चूर्ण|powder)                     0.82
# P(परिवार|family)                    0.82
# P(भी|well)                          0.81
# P(भूमिका|role)                      0.81
# P(तीन|three)                        0.81
# P(महिला|woman)                      0.81
# P(अवधि|period)                      0.81
# P(सक्रिय|active)                    0.81
# P(माइग्रेन|migraine)                0.81
# P(ऊर्जा|energy)                     0.81
# P(घी|ghee)                          0.81
# P(गंभीर|serious)                     0.8
# P(राष्ट्रीय|national)                 0.8
# P(लाल|red)                           0.8
# P(5|5)                               0.8
# P(स्वस्थ|healthy)                    0.8
# P(जनपदों|districts)                  0.8
# P(साथी|partner)                      0.8
# P(कब्ज|constipation)                 0.8
# P(50|50)                             0.8
# P(सलाद|salad)                        0.8
# P(एक|one)                            0.8
# P(एसिड|acid)                         0.8
# P(फल|fruit)                          0.8
# P(एचपीवी|hpv)                       0.79
# P(छोटीमाता|pox)                     0.79
# P(पदार्थ|substance)                 0.79
# P(रूप|form)                         0.79
# P(लंच|lunch)                        0.79
# P(हड्डियों|bones)                   0.79
# P(ध्यान|attention)                  0.79
# P(गैस्ट्रोएंट्राइट्स|gastroenteritis)                0.79
# P(हजार|thousand)                    0.79
# P(संख्या|number)                    0.79
# P(30|30)                            0.79
# P(हर|every)                         0.78
# P(घर|home)                          0.78
# P(लिए|order)                        0.78
# P(प्रोटीन|protein)                  0.78
# P(विकसित|developed)                 0.78
# P(मूत्राशय|bladder)                 0.78
# P(इच्छा|desire)                     0.78
# P(सतह|surface)                      0.78
# P(95|95)                            0.78
# P(रस|juice)                         0.78
# P(खाली|empty)                       0.78
# P(जहाँ|where)                       0.77
# P(क्यों|why)                        0.77
# P(यौन|sexual)                       0.77
# P(अमेरिका|america)                  0.77
# P(राज्य|state)                      0.77
# P(जटिल|complicated)                 0.77
# P(होता|happens)                     0.77
# P(दवा|medicine)                     0.76
# P(संतुलन|balance)                   0.76
# P(अनुपात|proportion)                0.76
# P(कम|reduce)                        0.76
# P(हृदय|heart)                       0.76
# P(रंग|color)                        0.76
# P(बैग|bag)                          0.76
# P(ग्राम|gram)                       0.76
# P(व्यवहार|behavior)                 0.76
# P(इन्फ्रारेड|infrared)                0.76
# P(घास|grass)                        0.75
# P(लार|saliva)                       0.75
# P(चावल|rice)                        0.75
# P(से|than)                          0.75
# P(प्याज|onion)                      0.75
# P(संगीत|music)                      0.75
# P(दूध|milk)                         0.75
# P(अदरक|ginger)                      0.75
# P(समाज|society)                     0.75
# P(लगभग|approximately)                0.75
# P(सुबह|morning)                     0.74
# P(जोड़ों|joints)                     0.74
# P(7|7)                              0.74
# P(प्राथमिक|primary)                 0.74
# P(उपयोगी|useful)                    0.74
# P(देशों|countries)                  0.74
# P(सौ|hundred)                       0.74
# P(उत्तेजना|excitement)                0.74
# P(कि|that)                          0.74
# P(गैस|gas)                          0.74
# P(मृत्यु|mortality)                 0.74
# P(एग्जाम|exam)                      0.74
# P(सेरीबेलम|cerebellum)                0.74
# P(नियमित|regular)                   0.73
# P(है|is)                            0.73
# P(टेनिस|tennis)                     0.73
# P(सफल|successful)                   0.73
# P(अनुसार|according)                 0.73

# %%
def translate_sentence(sentence, tef, file):
    '''
    takes the best translation of an hindi word
    and appends to eng sentence
    '''
    global predicted_eng
    eng_sentence = []
    print("hin:",sentence)
    
    tokens = sentence.split(" ")
    for idx, token in enumerate(tokens):
        probabilities = []
        eng_words = []
#         print("token id, token", idx, token)
        max_score = -1
        max_eng_word = ""
        for k, v in tef.items():
            if token == k[0]:
                probabilities.append(v)
                eng_words.append(k[1])
#             print(f'{k[0]} - {v}')
#         probabilities = list(tef[token].values())
#         eng_words = list(tef[token].keys())
        for tef_index, prob in enumerate(probabilities):
            if prob > max_score:
                max_score = prob
                max_eng_word = eng_words[tef_index]
        
        eng_sentence.append(max_eng_word)
#         predicted_eng.append(max_eng_word)
    
    eng_sentence = " ".join(eng_sentence)
    print("eng:", eng_sentence)
    file.write(eng_sentence)
    file.write("\n")
    
    return eng_sentence

# %%
def test_model(dataset, tef):
#     tef = np.load('./models/IBMmodel1tef.npy')
    file = open("dev_translations.txt", 'w+')
    translated_data = []
    for sentence in dataset:
        translation = translate_sentence(sentence, tef, file)
        translated_data.append(translation)
    
    file.close()
    return translated_data

# %%
predicted_translations = test_model(raw_sentences_test_hi, tef)
# Out:
# hin: ताजा साँसें और चमचमाते दाँत आपके व्यक्तित्व को निखारते हैं ।
# eng: freshly breathing and  teeth your personality responsible  are .
# hin: दाँतों से आपका आत्मविश्‍वास भी बढ़ता है ।
# eng: teeth from ease  also malfunction is .
# hin: हमारे मसूढ़ों और दाँतों के बीच बैक्टीरिया मौजूद होते हैं ।
# eng: our  and teeth near between bacteria present dried are .
# hin: ये दाँतों को गंदा और साँसों को बदबूदार बना देते हैं ।
# eng: 2-3 teeth responsible dirty and  responsible  makes advises are .
# hin: यहाँ दिए कुछ आसान नुस्खों की मदद से आप अपने दाँतों को स्वच्छ और साँसों को ताजा रख सकते हैं ।
# eng: here glaxosmithkline some easy  comprehensive helps from you 's teeth responsible clean and  responsible freshly pillow broken are .
# hin: दाँतों को ठीक से साफ करें ।
# eng: teeth responsible cured from clean nets .
# hin: दाँतों को ठीक से साफ करने में दो से तीन मिनट का समय लगता है ।
# eng: teeth responsible cured from clean doing in two from three minutes original time starts is .
# hin: लेकिन ज्यादातर लोग इसके लिए एक मिनट से भी कम समय देते हैं ।
# eng: but angry people motion order one minutes from also less time advises are .
# hin: खूब पानी पीएँ ।
# eng: sweet water  .
# hin: मुँह सूखने पर बैक्टीरिया हमला तेज कर देते हैं ।
# eng: mouth drying on bacteria attacks bright infect advises are .
# hin: इससे साँसों से बदबू आने लगती है ।
# eng: phytoestrogen  from abstinence coming smoothness is .
# hin: खूब पानी पीने से न केवल खाने के बचे - खुचे टुकड़े साफ हो जाते हैं , बल्कि लार भी बनती है ।
# eng: sweet water drinking from neither only eating near chocolate -   clean dry kits are , just saliva also grave is .
# hin: मुँह साफ रखने में लार की खास भूमिका होती है ।
# eng: mouth clean maintaining in saliva comprehensive unmarried role smooth is .
# hin: लार उन बैक्टीरिया को नष्ट करती है जो साँसों में बदबू पैदा करते हैं ।
# eng: saliva females bacteria responsible destroyed try is whatever  in abstinence chaos junction are .
# hin: चबाएँ शुगर रहित चुइंग गम ।
# eng:  fasting fibroids   .
# hin: चुइंग गम चबाने से लार बनती है ।
# eng:   freshened from saliva grave is .
# hin: चुइंग गम से दाँतों को साफ रखने में मदद मिलती है ।
# eng:   from teeth responsible clean maintaining in helps predominantly is .
# hin: शुगर युक्त गम को सेहत के लिए अच्छा नहीं माना जाता ।
# eng: fasting containing  responsible composition near order good no believed capsular .
# hin: इसलिए डेंटिस्ट शुगर युक्त गम को खाने की सलाह नहीं देते ।
# eng: therefore  fasting containing  responsible eating comprehensive advice no advises .
# hin: नियमित रूप से कराएँ दाँतों की जाँच ।
# eng: regular form from allergy teeth comprehensive tested .
# hin: दंतचिकित्सक से दाँतों की जाँच नियमित रूप से कराएँ ।
# eng: dentist from teeth comprehensive tested regular form from allergy .
# hin: वे दाँतों की छोटी - मोटी समस्या को आसानी से सुलझा देते हैं ।
# eng: they teeth comprehensive small - thick problem responsible easily from mystery advises are .
# hin: खाने के बाद मुँह साफ करें ।
# eng: eating near after mouth clean nets .
# hin: हर बार खाने के बाद पानी से मुँह जरूर साफ करें ।
# eng: every times eating near after water from mouth node clean nets .
# hin: इससे खाने के बचे हुए टुकड़े साफ हो जाते हैं ।
# eng: phytoestrogen eating near chocolate running  clean dry kits are .
# hin: नींबू और नमक के मिश्रण से दाँत साफ करें ।
# eng: lemon and salt near mixture from teeth clean nets .
# hin: एक चम्मच में नमक लेकर उसमें तीन से चार बूंदें नींबू की डाल लें ।
# eng: one spoon in salt report greener three from four cumin lemon comprehensive peeling take .
# hin: हर हफ्ते इस मिश्रण से दाँतों को साफ करें ।
# eng: every cup this mixture from teeth responsible clean nets .
# hin: इससे न केवल दाँत चमचमाने लगते हैं ।
# eng: phytoestrogen neither only teeth  falling are .
# hin: बल्कि साँसों की दुर्गंध से भी छुटकारा मिलता है ।
# eng: just  comprehensive odour from also rid swelled is .
# hin: सेहत है तो सब है ।
# eng: composition is then clue is .
# hin: आज की व्यस्त जिंदगी में खुद को स्वस्थ रखना किसी चुनौती से कम नहीं ।
# eng: today comprehensive busy ageing in own responsible healthy kept any sensitive from less no .
# hin: लेकिन खान-पान पर ध्यान और जीवनशैली में थोड़ा बदलाव लाकर आप खुद को स्वस्थ रख सकते हैं ।
# eng: but abstinence on attention and untreatable in summers change advised you own responsible healthy pillow broken are .
# hin: कम वसायुक्त आहार का करें सेवन ।
# eng: less  nutritious original nets consumption .
# hin: खाना वही खाएँ जिसमें कम वसा और फाइबर ज्यादा हो ।
# eng: eaten pencil chapatti looking less fat and fiber more dry .
# hin: फलों और सब्जियों में ऐसा ही अनुपात रहता है ।
# eng: fruits and vegetable in material only proportion stays is .
# hin: कम वसा और फाइबर वाले खाने से वजन नियंत्रित करने में मदद मिलती है ।
# eng: less fat and fiber taught eating from weight controlled doing in helps predominantly is .
# hin: कम वसा और फाइबर वाले खाने से आप कई बीमारियों से भी दूर रहते हैं ।
# eng: less fat and fiber taught eating from you many diseases from also away act are .
# hin: नमक और शराब का सेवन कम करें ।
# eng: salt and alcohol original consumption less nets .
# hin: ब्लड प्रेशर और कोलेस्ट्राल को नियंत्रित करने के लिए नमक और शराब का सेवन कम से कम मात्रा में करें ।
# eng: depression veins and fibers responsible controlled doing near order salt and alcohol original consumption less from less quantity in nets .
# hin: बंद करें धूम्रपान ।
# eng: closed nets smoking .
# hin: धूम्रपान करने से कैंसर समेत कई बीमारियों का खतरा होता है ।
# eng: smoking doing from cancer thumbs many diseases original danger happens is .
# hin: इसे छोड़ने की पूरी कोशिश करें ।
# eng: episode cooperate comprehensive completely attempted nets .
# hin: रोज करें व्यायाम ।
# eng: applies nets exercise .
# hin: अपनी रोज की दिनचर्या में व्यायाम को जरूर शामिल करें ।
# eng: captivity applies comprehensive 155 in exercise responsible node include nets .
# hin: नियमित व्यायाम से आप हृदय रोग , कोलन कैंसर , ब्लड प्रेशर और डायबिटीज जैसी बीमारियों से बचाव कर सकते हैं ।
# eng: regular exercise from you heart disease ,  cancer , depression veins and diabetes activities diseases from prevention infect broken are .
# hin: करते रहें हल्की - फुल्की शारीरिक गतिविधियाँ ।
# eng: junction cherries stroll -  physical  .
# hin: सीढ़ी चढ़ना , बागवानी , घर के छोटे - मोटे काम या डांस करने जैसी हल्की - फुल्की शारीरिक गतिविधियाँ जरूर करते रहें ।
# eng:   , newest , home near small - obese work or dance doing activities stroll -  physical  node junction cherries .
# hin: इनसे शरीर में लचीलापन बना रहता है ।
# eng: abrasion body in disturbance makes stays is .
# hin: यदि लगातार बुखार आ रहा है तो उसकी जाँच अवश्य करायें ।
# eng: if continuously fever deformation engulfing is then popcorn tested certainly  .
# hin: मलेरिया , कालाजार , यक्ष्मा की शुरुआत बुखार से ही होती है ।
# eng: malaria ,  ,  comprehensive beginning fever from only smooth is .
# hin: गर्मी का मौसम शुरू हो चुका है ।
# eng: summer original weather onset dry already is .
# hin: बासी भोजन व सड़क किनारे बिकने वाले सामान का सेवन नहीं करें ।
# eng:  food vegetable  sides  taught  original consumption no nets .
# hin: बच्चों को फास्ट फूड , कुरकुरे , आइसक्रीम नहीं खिलायें ।
# eng: children responsible   ,  ,  no  .
# hin: कै-दस्त होने पर नमक और चीनी का घोल या ओ.आर.एस पिलायें ।
# eng:  occurring on salt and 83 original ashwini or   .
# hin: साफ पानी अधिक से अधिक पीयें ।
# eng: clean water excessive from excessive nitrogen .
# hin: लगातार बुखार से पीड़ित हो ?
# eng: continuously fever from suffering dry what
# hin: कालाजार , मलेरिया या फिर हाई फीवर हो सकता है ।
# eng:  , malaria or else flexion  dry can is .
# hin: मेरा बच्चा दस्त और बुखार दोनों पीड़ित है ?
# eng:  useless loose and fever both suffering is what
# hin: पहले ओ.आर.एस. का घोल पिलायें , इसके बाद बच्चे को किसी शिशु रोग विशेषज्ञ से शीघ्र दिखायें ।
# eng: before  original ashwini  , motion after child responsible any infant disease specialist from early  .
# hin: ढाई - तीन वर्षो से हर दो - तीन माह पर फीवर हो जाता है ।
# eng:  - three i from every two - three months on  dry capsular is .
# hin: यही नहीं जीभ पर सफेद परत जम जाती है ।
# eng: perhaps no tongue on white layer clotted released is .
# hin: पानी की मात्रा ज्यादा लें और यूरीन कल्चर जाँच करायें ।
# eng: water comprehensive quantity more take and   tested  .
# hin: कालाजार के प्रारंभिक लक्षण क्या हैं ?RD_PUNC
# eng:  near mistake symptoms what are
# hin: कुछ दिनों से हल्का फीवर रहता है ।
# eng: some days from meals  stays is .
# hin: बुखार की जाँच करें और अन्य जरूरी जाँच के पश्चात ही कालाजार प्रमाणित हो सकता है ।
# eng: fever comprehensive tested nets and other aforesaid tested near post only  proved dry can is .
# hin: मेटासिन की गोली देने से बुखार उतर जाता है और फिर 103 तक बुखार चढ़ जाता है ।
# eng:  comprehensive natrum giving from fever bhang capsular is and else  till fever  capsular is .
# hin: एक्सरे , टीसी-डीसी नार्मल है ।
# eng: x-ray ,   is .
# hin: चार - चार घंटे पर फीवर को मापें ।
# eng: four - four hours on  responsible  .
# hin: अगर 100 से ज्यादा फीवर हो तो पैरासीटामोल की गोली दें और किसी औषधि विशेषज्ञ चिकित्सक से परामर्श लें ।
# eng: cautious 100 from more  dry then  comprehensive natrum switch and any stores specialist doctors from my take .
# hin: एच.आई.वी. क्या है ?
# eng: hiv what is what
# hin: यह कैसे होता है ?RD_PUNC
# eng: this how happens is
# hin: बचाव के उपाय बताएँ ?
# eng: prevention near solution  what
# hin: यह एक प्रकार का वायरस होता है ।
# eng: this one type original virus happens is .
# hin: इसका फैलाव मुख्यत: असुरक्षित यौन संबंध , संक्रमित सूई , संक्रमित रक्त व माँ से बच्चों में होता है ।
# eng: regrettable laser thymine  sexual relation , infected  , infected blood vegetable mother from children in happens is .
# hin: इससे शरीर की रोग प्रतिरोधक क्षमता कम होती जाती है ।
# eng: phytoestrogen body comprehensive disease strength capacity less smooth released is .
# hin: बोन टीवी की क्या पहचान है तथा इसका क्या इलाज है ?
# eng: densitometry tv comprehensive what identification is cosmetics regrettable what treatment is what
# hin: हड्डियों में दर्द , लगातार बुखार , भले ही यह कम क्यों न हो या बुखार शाम में बढ़ जाये , दर्द के साथ-साथ हड्डियों में विकृति आ जाये तो यह बोन टीबी का लक्षण है ।
# eng: bones in pain , continuously fever , psychiatrists only this less why neither dry or fever evening in increases orange , pain near beautiful bones in deformity deformation orange then this densitometry  original symptoms is .
# hin: इससे हड्डियाँ कमजोर हो जाती हैं और गलने लगती हैं ।
# eng: phytoestrogen break weak dry released are and  smoothness are .
# hin: इस परिस्थिति में लकवा भी मार सकता है ।
# eng: this  in paralysis also  can is .
# hin: इसकी जाँच के लिए डिजिटल एक्सरे , एम.आर.आई. करायें , टीबी की दवा एक वर्ष तक लें एवं विशेषज्ञ चिकित्सक से परामर्श लें ।
# eng: location tested near order  x-ray , radiations  ,  comprehensive medicine one year till take stable specialist doctors from my take .
# hin: रात में सोते समय शरीर पर एक चादर जरूर रखे एवं पंखा कम से कम चलायें ।
# eng: night in sleeping time body on one  node pollute stable  less from less  .
# hin: इससे अगर अपने आप सही महसूस नहीं करते हैं तो एन्टीएलर्जिक टेबलेट दस दिनों तक लें ।
# eng: phytoestrogen cautious 's you correct feeling no junction are then   ten days till take .
# hin: बच्चों को घमौंरी हो रही है क्या करें ?
# eng: children responsible  dry proving is what nets what
# hin: डायरिया का घरेलू उपचार क्या है ?
# eng:  original domestic treatment what is what
# hin: एक गिलास पानी में दो चम्मच चीनी एवं एक चुटकी नमक डालकर उबालकर दें ।
# eng: one glass water in two spoon 83 stable one pinch salt gargling boiled switch .
# hin: धूप के कारण क्या कालाजार रोग होता है ?
# eng: sunlight near reason what  disease happens is what
# hin: क्या गर्मी में इसका प्रकोप बढ़ जाता है ?
# eng: what summer in regrettable outburst increases capsular is what
# hin: कालाजार बालू मक्खी के काटने से होता है ।
# eng:    near biting from happens is .
# hin: इसका उपचार सभी अस्पतालों में है ।
# eng: regrettable treatment all superintendant in is .
# hin: इसके लिए अब टेबलेट भी उपलब्ध हैं ।
# eng: motion order now  also available are .
# hin: किसी बच्चे को कुकुर खाँसी हो जाये तो क्या करना चाहिये ?
# eng: any child responsible  coughs dry orange then what encouraging anus what
# hin: बच्चे को डीपीटी का टीका लगायें ।
# eng: child responsible  original vaccine apply .
# hin: किसी विशेषज्ञ चिकित्सक से दिखायें तथा खाँसी के लिए बलगम की जाँच करायें ।
# eng: any specialist doctors from  cosmetics coughs near order phlegm comprehensive tested  .
# hin: अपनी आँखों की देखभाल को लेकर आप कितने जागरूक हैं ?
# eng: captivity eyes comprehensive care responsible report you vigor aware are what
# hin: हर छह माह में करें आँखों की जाँच ।
# eng: every  months in nets eyes comprehensive tested .
# hin: चश्मे या कांटैक्ट लेंस का रखरखाव करें ।
# eng: improvement or  lens original  nets .
# hin: नियमित आँखें धोना ।
# eng: regular tv sabudana .
# hin: लेकिन इन सबके साथ अगर आप अपने खान -|RD_PUNC पान पर थोड़ा सा ध्यान दें ।
# eng: but these highway along cautious you 's   pan on summers apparatus attention switch .
# hin: तो न सिर्फ आपकी आँखों की रोशनी बेहतर हो सकती है ।
# eng: then neither aged your eyes comprehensive sight better dry may is .
# hin: लेकिन 12 - 15 सीटों वाला यह टिवन ओटर प्लेन मालदीव जैसे आर्कीपेलेगो ( द्वीप समूह ) को घूमने के लिए निर्विवाद रूप से श्रेष्‍ठ है ।
# eng: but 12 - 15  six this     like  -lrb- afric mass -lrb- responsible  near order  form from  is .
# hin: पानी की सतह पर स्पीड बोट की तरह दौड़ते हुए यह कब हवा में उठ जाता है , पता नहीं चलता ।
# eng: water comprehensive surface on mph  comprehensive sticky  running this immemorial air in disorder capsular is , known no learns .
# hin: पूरी उड़ान में आपको आम हवाई जहाजों की उड़ान का अनुभव नहीं होता ।
# eng: completely  in others mango models  comprehensive  original felt no happens .
# hin: हर वक्‍त आपकी निगाहें खिड़की से नीचे को ताकती रहती हैं - मालदीव के अलग-अलग शेड्‍स के नीले पानी में रिजॉर्ट द्वीपों व कोरल द्वीपों को निहारते हुए ।
# eng: every  your   from below responsible  continues are -  near swellings  near  water in   vegetable   responsible  running .
# hin: सब कुछ कितना साफ दिखता है ।
# eng: clue some how clean ray is .
# hin: मालदीव में दो ही सी प्लेन कंपनियाँ हैं ।
# eng:  in two only c   are .
# hin: ट्राँस मालदीवियन इन्हीं में से एक है जिसके पास बीस सी प्लेन है ।
# eng:   honeybee in from one is proposal educated tribulus c  is .
# hin: आप चाहें तो लगभग चार हजार रुपये ( प्रति व्यक्‍ति ) में घंटेभर की हवाई सैर कर सकते हैं या फिर पूरा सी प्लेन अपनी दिनभर की तफरीह के लिए किराये पर ले सकते हैं ( बशर्ते जेब गहरी हो ) ।
# eng: you transfer then approximately four thousand  -lrb- per  -lrb- in  comprehensive models routine infect broken are or else compensate c  captivity  comprehensive  near order  on takes broken are -lrb-   deep dry -lrb- .
# hin: वैसे अगर आप माले द्वीप से परे किसी द्वीप पर जाएँ तो सी प्लेन का सफर जरूरी होगा क्योंकि विभिन्न द्वीपों के बीच सफर का यही जरिया है ।
# eng: though cautious you  afric from completing any afric on someone then c  original meals aforesaid would because various  near between meals original perhaps  is .
# hin: और वो एक ऐसा सफर होता है जिसके खत्म होने का मन शायद आपका कभी न करे ।
# eng: and  one material meals happens is proposal intensity occurring original wish perhaps ease never neither illusion .
# hin: सी प्लेन 12 किलोमीटर से लेकर 183 किलोमीटर ( उत्तम में मावीलेवारू ) तक का सफर मालदीव के द्वीपों में करते हैं ।
# eng: c  12  from report   -lrb- considered in  -lrb- till original meals  near  in junction are .
# hin: हम माले के अहमदी बाजार में राजधानी की सबसे बड़ी एंटीक व सोवेनियर दुकान में थे ।
# eng: we  near  market in  comprehensive most big  vegetable  shop in egyptian .
# hin: सारे सेल्समैन मालदीव के राष्‍ट्रपति मोहम्मद नाशीद द्वारा एक दिन पहले कोपेनहेगन में विश्‍व जलवायु सम्मेलन में दिए गए भाषण को बड़े ध्यान से सुन रहे थे ।
# eng: entire   near    through one day before  in organisation rampant suggested in glaxosmithkline went nobel responsible prudence attention from something cherry egyptian .
# hin: ईमानदारी से कहूँ तो मैंने किसी हिंदुस्तानी को राष्‍ट्रपतियों या प्रधानमंत्री के भाषणों को इतने ध्यान से सुनते नहीं देखा ।
# eng:  from  then casually any  responsible  or  near  responsible microscope attention from  no seen .
# hin: लेकिन जब इस धरती की एक नायाब रचना के अस्तित्त्व का ही सवाल हो तो , इतनी गंभीरता लाजिमी ही थी ।
# eng: but when this  comprehensive one  creation near  original only  dry then , omniavailable seriously commercialisation only 2000 .
# hin: कई लोगों ने अक्टूबर में मालदीव की कैबिनेट द्वारा पानी के अंदर की गई बैठक को भले ही टोटका समझा हो , लेकिन मालदीव जाकर लगता है कि अगर प्रकृति का कोप इसे हमसे छीन ले तो दुनिया कितनी दरिद्र हो जाएगी ।
# eng: many people nature  in  comprehensive  through water near entering comprehensive hypertension expense responsible psychiatrists only   dry , but  dentist starts is that cautious nature original  episode ours  takes then world equipment  dry  .
# hin: वहाँ की सुंदरता में कुछ ऐसा ही खास है ।
# eng: central comprehensive  in some material only unmarried is .
# hin: उस छोटे से देश में मानो इतनी खूबसूरती समाती नहीं ।
# eng: ovary small from country in  omniavailable   no .
# hin: बाजार की उस सैर से वापस अपने क्रूज पर जाने के लिए जेट्‍टी की तरफ लौटते हुए , जब निगाहें बरबस सड़क के साथ-साथ चलते समंदर के पानी में गई तो अहसास हुआ कि यहाँ के लोग इस खूबसूरती की कीमत किस हद तक समझते हैं ।
# eng: market comprehensive ovary routine from burps 's  on consequence near order  comprehensive cheeks  running , when   road near beautiful congenital  near water in hypertension then  happened that here near people this  comprehensive  dilemma extent till  are .
# hin: पानी इतना साफ था कि लैंपपोस्ट की रोशनी में नीचे कई मीटर गहराई में तैरती मछलियाँ अपने सारे रंगों के साथ दिखाई दे रही थीं ।
# eng: water endurance clean had that  comprehensive sight in below many metre depths in   's entire  near along visible pass proving seventeenth .
# hin: यह समंदर का वो हिस्सा था जो शहर से एकदम सटा हुआ था ।
# eng: this  original  prey had whatever  from !  happened had .
# hin: आप भारत के किसी शहर से सटे हुए समुद्र या नदी के पानी में कुछ सेंटीमीटर भी साफ देख सकें तो खुद को खुशकिस्मत पाएँगे ।
# eng: you india near any  from  running  or banks near water in some mixture also clean see mystery then own responsible  count .
# hin: एमवी एक्वामैरिन पर लौटते हुए माले में बिताए हुए शाम के दो घंटे जेहन में घूम रहे थे ।
# eng:   on  running  in  running evening near two hours  in  cherry egyptian .
# hin: कोरल रीफ ( मूँगा चट्‍टानें ) यहाँ का जीवन हैं ।
# eng:   -lrb-   -lrb- here original life are .
# hin: यहाँ तक की आपको कब्रों पर लगे पत्थरों पर भी मूँगा चट्‍टानें मिल जाएँगी ।
# eng: here till comprehensive others  on engrossed  on also   counselling  .
# hin: राष्‍ट्रपति नाशीद का भाषण सुनने के कुछ देर पहले हम उनके सरकारी आवास के बाहर खड़े थे ।
# eng:   original nobel hear near some late before we sized non-government  near outside standing egyptian .
# hin: यकीन नहीं होता था कि हम किसी देश की सर्वोच्च शख्सियत के आवास के आगे थे , दूर-दूर तक कोई सुरक्षाकर्मी नहीं था ।
# eng:  no happens had that we any country comprehensive   near  near front egyptian ,  till shadowiness  no had .
# hin: मजे से हम उसके बंगले के दरवाजे से अंदर हाथ बढ़ाकर महज पचास मीटर दूर बगीचे व बरामदे के फोटो खींच रहे थे ।
# eng:  from we his  near  from entering hand comprehension  fifty metre away garden vegetable  near  sucks cherry egyptian .
# hin: क्या आप भारत में किसी अदने से नेता के घर के बारे में ऐसा सोच सकते हैं ?
# eng: what you india in any  from  near home near regarding in material thought broken are what
# hin: पता तो यह भी चला कि राष्‍ट्रपति कभी - कभार पैदल ही सड़कें पार करते हुए दो ब्लॉक आगे अपने दफ्तर में पहुँच जाते हैं ।
# eng: known then this also researches that  never -   only  crossing junction running two  front 's office in harmed kits are .
# hin: मालदीव के बारे में हर बात अभिभूत करने वाली थी ।
# eng:  near regarding in every thing  doing responsible 2000 .
# hin: इसीलिए मुझे अगले दिन का बेसब्री से इंतजार था ।
# eng: spoonerism consultation next day original  from  had .
# hin: इल्हाम था कि वह दिन खास होने वाला था ।
# eng:  had that he day unmarried occurring six had .
# hin: सवेरे क्रूज से एक नाव हमें एयरपोर्ट आईलैंड लेकर आई ।
# eng:   from one  us   report somehow .
# hin: वहाँ से हम रनवे का चक्कर काटते हुए पहुँचे ट्राँस मालदीवियन के बेस पर ।
# eng: central from we  original stroll anopheles running    near superintendant on .
# hin: पिछली शाम जब क्रूज माले के निकट पहुँच रहा था तो हमने ऊपर से गुजर रहे सी प्लेन को तुरंत पहचान लिया ।
# eng:  evening when   near relatives harmed engulfing had then origin representation from captivities cherry c  responsible immediately identification generating .
# hin: इतनी तस्वीरें जो देखी थी , उसकी ।
# eng: omniavailable  whatever old 2000 , popcorn .
# hin: लेकिन तब गुमान न था कि अगले दिन उसमें सवारी का मौका मिलेगा ।
# eng: but count  neither had that next day greener  original  press .
# hin: ट्रॉस मालदीवियन के सी प्लेन से हम एक सौ पाँच किमी दूर रंगाली द्वीप जाने वाले थे ।
# eng:   near c  from we one hundred five  away  afric consequence taught egyptian .
# hin: लगभग हजार मीटर की ऊँचाई तक उड़ने वाले सी प्लेन से मालदीव के समुद्र में फैले पड़े सैकड़ों रिजॉर्ट व कोरल द्वीपों को देखना अविस्मरणीय था ।
# eng: approximately thousand metre comprehensive hundreds till  taught c  from  near  in callosum-the measured   vegetable   responsible otherwise  had .
# hin: पानी की यह खूबसूरती कहीं और नहीं मिलेगी ।
# eng: water comprehensive this  anywhere and no  .
# hin: रोमांच व उत्साह से साँसें थाम देने वाली उड़ान थी वह ।
# eng:  vegetable hundreds from breathing  giving responsible  2000 he .
# hin: लेकिन रंगाली द्वीप पर हिल्टन होटल्स के कोनराड रिजॉर्ट पहुँचकर लगा मानो हम किसी दूसरी दुनिया में पहुँच गए हों ।
# eng: but  afric on   near   acute estimate  we any cell world in harmed went psychiatrists .
# hin: ऐसी दुनिया में , जिसका बाहर की किसी दुनिया से कोई वास्ता नहीं था ।
# eng: such world in , creative outside comprehensive any world from shadowiness  no had .
# hin: वास्ता इस तरह भी नहीं था कि वहाँ जैसी खूबसूरती या विलासिता बाहर मिलना मुश्‍किल था ।
# eng:  this sticky also no had that central activities  or  outside   had .
# hin: कोनराड पर सैर पैदल भी हो सकती है या बैटरी चालित गाड़ी से भी ।
# eng:  on routine  also dry may is or    from also .
# hin: जेट्‍टी से मुख्य द्वीप तक जाते हुए पुल के दोनों ओर जलजीवन का नजारा अद्‍भुत था ।
# eng:  from main afric till kits running bridge near both side  original   had .
# hin: अभी हम आस-पास की प्रकृति से खुद को सहज भी नहीं कर पाए थे , कि ऐसी जगह पहुँच गए , अकल्पनीय थी ।
# eng: date we nearby comprehensive nature from own responsible casually also no infect dust egyptian , that such place harmed went ,  2000 .
# hin: सीढ़ियों से कई मीटर नीचे समुद्र के पानी में उतरते हुए हम शीशे के ऐसे कमरे में पहुँच गए जो पानी के अंदर था ।
# eng:  from many metre below  near water in  running we mirror near such entry in harmed went whatever water near entering had .
# hin: वह कमरा दरअसल एक डाइनिंग रूम था ।
# eng: he  hole one   had .
# hin: सब तरफ शीशों के पार हम विलक्षण किस्म की छोटी - बड़ी मछलियाँ , कोरल्स , स्नोर्कलिंग व स्कूबा डाइविंग करते हुए इंसान देख सकते थे ।
# eng: clue cheeks  near crossing we  beer comprehensive small - big  ,  ,  vegetable   junction running marrow see broken egyptian .
# hin: वहाँ सजी मेजों पर बैठकर खाने की कल्पना ही अपने आप में बेहद रोमांचित कर देने वाली थी ।
# eng: central   on sitting eating comprehensive imagined only 's you in ease  infect giving responsible 2000 .
# hin: माले से सी प्लेन में इस द्वीप पर आकर इसे देखने और अंडरवाटर लंच करने का किराया ही एक आदमी के लिए 47 हजार रुपये है ।
# eng:  from c  in this afric on repeated episode seeing and  lunch doing original expense only one oxygen near order  thousand  is .
# hin: वहाँ से लौटने का मन न था ।
# eng: central from  original wish neither had .
# hin: हम लोग अपने पासपोर्ट पानी में बहा देने को तैयार थे ।
# eng: we people 's  water in  giving responsible prepared egyptian .
# hin: लेकिन जानते थे , यह मुमकिन नहीं था ।
# eng: but know egyptian , this bending no had .
# hin: भारी मन से इसी उम्मीद के साथ लौट पड़े कि फिर कभी , किसी मोड़ पर तकदीर यहाँ जरूर ले आएगी ।
# eng: crowd wish from similarly  near along return measured that else never , any  on  here node takes  .
# hin: कई दिनों से दिल्ली से बाहर जाने की योजना बना रहे थे लेकिन काम की व्यस्तता के चलते यह संभव नहीं हो पा रहा था ।
# eng: many days from  from outside consequence comprehensive scheme makes cherry egyptian but work comprehensive  near congenital this possible no dry rid engulfing had .
# hin: बचपन से वाइल्ड लाइफ का शौक था तो सोचा कि क्यों न इस बार जिम कार्बेट जाया जाए ।
# eng: childhood from   original  had then  that why neither this times    negative .
# hin: 2006 में लद्दाख में खारदूंगला पास से आगे पेगोंग लेक तक की बाइकिंग के बाद यह दूसरा बाइक टूर था ।
# eng: security in  in  educated from front   till comprehensive mountain near after this second   had .
# hin: 27 दिसंबर की तड़के हम दिल्ली से जिम कार्बेट के लिए रवाना हुए , लेकिन जिस जोशखरोश से निकले थे कोहरे ने हमारी रफ्तार रफूचक्कर कर दी ।
# eng:   comprehensive  we  from   near order  running , but instrument  from daring egyptian  nature our jog  infect given .
# hin: हापुड़ से गजरौला के बीच का सफर वाकई थकाऊ था ।
# eng:  from  near between original meals   had .
# hin: ऊपर से कोहरा और सामने खराब सड़क ।
# eng: representation from  and forward spoiled road .
# hin: कई बार तो लगा कि अब गिरे ।
# eng: many times then estimate that now  .
# hin: किसी तरह सुबह 8 बजे गजरौला पहुँचे ।
# eng: any sticky morning 8 secure   .
# hin: खैर हम 12 बजे रामनगर पहुँच गए ।
# eng:  we 12 secure  harmed went .
# hin: कार्बेट पार्क रामनगर से 20 किलोमीटर आगे है ।
# eng:    from 20  front is .
# hin: हमारा रिजॉर्ट पार्क के नजदीक ढिकुली में था , जिसकी बुकिंग हमने पहले ही करवा दी थी ।
# eng: crore   near nearby  in had , decrement  origin before only heard given 2000 .
# hin: उस दिन कुछ खास कार्यक्रम था नहीं हम ठंड होने के बावजूद पहले कोसी के किनारे घूमने गए ।
# eng: ovary day some unmarried program had no we sunlight occurring near  before  near sides  went .
# hin: दो - तीन घंटे वहाँ बिताने के बाद हम कार्बेट म्यूजियम निकल गए , जो बड़ी मुश्‍किल 2 किमी दूर धांगड़ी गेट के नजदीक था ।
# eng: two - three hours central spend near after we   unidirectional went , whatever big  2  away   near nearby had .
# hin: वहाँ से हम नीचे रामनगर घूमने चले गए ।
# eng: central from we below   links went .
# hin: लौटते देर शाम हो गई ।
# eng:  late evening dry hypertension .
# hin: दिल्ली से ठान कर निकला था कि जंगल में छुट्‍टा घूमता शेर जरूर देखूँगा तो पूरी रात सपने में मुझे शेर दिखाई देते रहे ।
# eng:  from  infect market had that  in    node  then completely night  in consultation  visible advises cherry .
# hin: रात की गहराइयों के बीच अचानक मुझे जबरदस्त दहाड़ सुनाई दी और उसके बाद तो जो कुत्तों ने भौंकना शुरू किया तो दो घंटे तक थमे नहीं ।
# eng: night comprehensive  near between sudden consultation relevant   given and his after then whatever  nature  onset were then two hours till  no .
# hin: लिहाजा पहले कालाढुंगी और कार्बेट फॉल घूमने का सुझाव आया ।
# eng: consequently before  and    original suggestions forward .
# hin: कालाढुंगी तीस किमी दूर है , जबकि कार्बेट फॉल रास्ते में पड़ता है ।
# eng:    away is , busy   flushed in combat is .
# hin: कालाढुंगी में जिम कार्बेट साहब का म्यूजियम है , जहाँ उनकी निजी जिंदगी से जुड़ी कुछ अहम चीजें रखी हैं ।
# eng:  in    original  is , where detect  ageing from connected some information things  are .
# hin: लौटते-लौटते साढ़े बारह बज गए ।
# eng:     went .
# hin: कालाढुंगी बेहद खूबसूरत जगह है , जिम कार्बेट इसी गाँब में आकर बसे थे ।
# eng:  ease  place is ,   similarly  in repeated  egyptian .
# hin: रिजॉर्ट पहुँचने पर सफारी जिप्सी हमारा इंतजार कर रही थी ।
# eng:  extra on   crore  infect proving 2000 .
# hin: बताया गया कि उन्होंने वहाँ की नंबर एक साइट बिजरानी में साइटिंग की व्यवस्था कराई है ।
# eng: told been that something central comprehensive finally one   in  comprehensive system rectifies is .
# hin: नंबर एक के बारे में पूछने पर बताया कि वहाँ ग्रासलैंड ज्यादा है और टाइगर इस दौरान ठंड से बचने के लिए उसी तरफ आते हैं ।
# eng: finally one near regarding in  on told that central  more is and tiger this during sunlight from vegetarianism near order strange cheeks shows are .
# hin: बिजरानी पहुँचते ही हमें एक गाइड दिया गया , जो चार घंटे घुमाने के ढाई सौ रुपये लेता है ।
# eng:  reach only us one  encouraged been , whatever four hours carry near  hundred  handles is .
# hin: हम अंदर जंगल के लिए रवाना हो गए ।
# eng: we entering  near order  dry went .
# hin: हमने वहाँ कई तरह के जानवर और हिरनों की कई प्रजातियाँ देखीं ।
# eng: origin central many sticky near  and  comprehensive many simpsaloni  .
# hin: अंदर हमने दो टस्कर हाथी देखे , जिनके लंबे-लंबे दाँत थे ।
# eng: entering origin two  elephant 65 , copulate  teeth egyptian .
# hin: मैंने जमकर फोटोग्राफी की ।
# eng: casually   comprehensive .
# hin: इस बीच गाइड ने टाइगर को ट्रैक करना शुरू कर दिया ।
# eng: this between  nature tiger responsible track encouraging onset infect encouraged .
# hin: गाइड ने बताया कि पार्क में तकरीबन 150 के आस-पास ही टाइगर हैं , जिनमें से हाल ही में कुछ मर चुके हैं ।
# eng:  nature told that  in 26 bodies near nearby only tiger are , abortions from recent only in some sheet cartilage are .
# hin: कई जगह हमें उनके पंजों के निशान भी दिखे , लेकिन टाइगर का दर्शन न मिलने से मैं उदास था ।
# eng: many place us sized  near mark also  , but tiger original  neither immunisation from i  had .
# hin: तीसरे दिन हमें दिल्ली लौटना था ।
# eng: third day us   had .
# hin: मेरे दिमाग में तो टाइगर का फितूर सवार था ।
# eng: my disorder in then tiger original   had .
# hin: तभी मुझे हल्द्वानी के अपने एक पुराने मित्र की याद आई ।
# eng: realize consultation  near 's one oldest  comprehensive remember somehow .
# hin: मैंने उसे ऐसे ही फोन लगा दिया ।
# eng: casually him such only  estimate encouraged .
# hin: मैंने उसे बताया कि मैं कार्बेट आया हुआ हूँ ।
# eng: casually him told that i  forward happened i .
# hin: उसने पूछा टाइगर देखा या नहीं ।
# eng: covered casually tiger seen or no .
# hin: उसके यह शब्द तीर की तरह चुभ गए ।
# eng: his this word  comprehensive sticky  went .
# hin: मैंने धीरे से कहा , नहीं ।
# eng: casually gradually from said , no .
# hin: पार्क में बाइक ले जाने की अनुमति नहीं थी ।
# eng:  in  takes consequence comprehensive  no 2000 .
# hin: हमें किसी ने सलाह दी कि आप अंदर के लिए सफारी ले लो ।
# eng: us any nature advice given that you entering near order  takes  .
# hin:
# eng:

# %%
from nltk.translate.ibm1 import IBMModel1
from nltk.translate import AlignedSent


def get_text(filename):
    sentences = []
    with open(filename,'r',encoding="utf8") as f:
        for sentence in f:
            sentences.append(sentence.split())
    return sentences

src_sentences = get_text('english test.txt')
trg_sentences = get_text('hindi test.txt')

bitext = []
for i in range(len(src_sentences)):
    bitext.append(AlignedSent(src_sentences[i], trg_sentences[i]))

ibm1 = IBMModel1(bitext, 5)

# %%
ibm1.train(bitext)

# %%
for i in bitext:
    print(i)
# Out:
# <AlignedSent: 'Fresh breath and shi...' -> 'ताजा साँसें और चमचमा...'>
# <AlignedSent: 'Your self-confidence...' -> 'दाँतों से आपका आत्मव...'>
# <AlignedSent: 'Bacteria stay betwee...' -> 'हमारे मसूढ़ों और दाँ...'>
# <AlignedSent: 'They make teeth dirt...' -> 'ये दाँतों को गंदा और...'>
# <AlignedSent: 'You may keep your te...' -> 'यहाँ दिए कुछ आसान नु...'>
# <AlignedSent: 'Clean your teeth pro...' -> 'दाँतों को ठीक से साफ...'>
# <AlignedSent: 'It takes two to thre...' -> 'दाँतों को ठीक से साफ...'>
# <AlignedSent: 'But most of the peop...' -> 'लेकिन ज्यादातर लोग इ...'>
# <AlignedSent: 'Drink plenty of wate...' -> 'खूब पानी पीएँ ।...'>
# <AlignedSent: 'Bacteria attack fast...' -> 'मुँह सूखने पर बैक्टी...'>
# <AlignedSent: 'With this stink come...' -> 'इससे साँसों से बदबू ...'>
# <AlignedSent: 'By drinking plenty o...' -> 'खूब पानी पीने से न क...'>
# <AlignedSent: 'Saliva has important...' -> 'मुँह साफ रखने में ला...'>
# <AlignedSent: 'Saliva destroys thos...' -> 'लार उन बैक्टीरिया को...'>
# <AlignedSent: 'Chew the sugar-free ...' -> 'चबाएँ शुगर रहित चुइं...'>
# <AlignedSent: 'Saliva is formed by ...' -> 'चुइंग गम चबाने से ला...'>
# <AlignedSent: 'Chewing gum helps in...' -> 'चुइंग गम से दाँतों क...'>
# <AlignedSent: 'Sugared chewing gum ...' -> 'शुगर युक्त गम को सेह...'>
# <AlignedSent: 'That is why dentists...' -> 'इसलिए डेंटिस्ट शुगर ...'>
# <AlignedSent: 'Get the teeth checke...' -> 'नियमित रूप से कराएँ ...'>
# <AlignedSent: 'Get the teeth checke...' -> 'दंतचिकित्सक से दाँतो...'>
# <AlignedSent: 'They solve small pro...' -> 'वे दाँतों की छोटी - ...'>
# <AlignedSent: 'Clean the mouth afte...' -> 'खाने के बाद मुँह साफ...'>
# <AlignedSent: 'Do clean the mouth e...' -> 'हर बार खाने के बाद प...'>
# <AlignedSent: 'The left-over pieces...' -> 'इससे खाने के बचे हुए...'>
# <AlignedSent: 'Clean the teeth with...' -> 'नींबू और नमक के मिश्...'>
# <AlignedSent: 'Taking a spoon of sa...' -> 'एक चम्मच में नमक लेक...'>
# <AlignedSent: 'Clean the teeth ever...' -> 'हर हफ्ते इस मिश्रण स...'>
# <AlignedSent: 'Not only teeth start...' -> 'इससे न केवल दाँत चमच...'>
# <AlignedSent: 'But one also gets re...' -> 'बल्कि साँसों की दुर्...'>
# <AlignedSent: 'If there is health t...' -> 'सेहत है तो सब है ।...'>
# <AlignedSent: 'It is not less than ...' -> 'आज की व्यस्त जिंदगी ...'>
# <AlignedSent: 'But you can keep you...' -> 'लेकिन खान-पान पर ध्य...'>
# <AlignedSent: 'Eat less fatty food ...' -> 'कम वसायुक्त आहार का ...'>
# <AlignedSent: 'Eat only that food i...' -> 'खाना वही खाएँ जिसमें...'>
# <AlignedSent: 'Fruits and vegetable...' -> 'फलों और सब्जियों में...'>
# <AlignedSent: 'We get helped in con...' -> 'कम वसा और फाइबर वाले...'>
# <AlignedSent: 'You keep yourself fa...' -> 'कम वसा और फाइबर वाले...'>
# <AlignedSent: 'Take less salt and a...' -> 'नमक और शराब का सेवन ...'>
# <AlignedSent: 'Take the least quant...' -> 'ब्लड प्रेशर और कोलेस...'>
# <AlignedSent: 'Stop smoking ....' -> 'बंद करें धूम्रपान ।...'>
# <AlignedSent: 'There is a danger of...' -> 'धूम्रपान करने से कैं...'>
# <AlignedSent: 'Try your best to qui...' -> 'इसे छोड़ने की पूरी क...'>
# <AlignedSent: 'Exercise daily ....' -> 'रोज करें व्यायाम ।...'>
# <AlignedSent: 'You must include exe...' -> 'अपनी रोज की दिनचर्या...'>
# <AlignedSent: 'You can prevent hear...' -> 'नियमित व्यायाम से आप...'>
# <AlignedSent: 'Keep doing light phy...' -> 'करते रहें हल्की - फु...'>
# <AlignedSent: 'Keep doing small phy...' -> 'सीढ़ी चढ़ना , बागवान...'>
# <AlignedSent: 'These retain the fle...' -> 'इनसे शरीर में लचीलाप...'>
# <AlignedSent: 'If fever comes conti...' -> 'यदि लगातार बुखार आ र...'>
# <AlignedSent: 'Malaria , kalajar , ...' -> 'मलेरिया , कालाजार , ...'>
# <AlignedSent: 'Summer season has st...' -> 'गर्मी का मौसम शुरू ह...'>
# <AlignedSent: 'Do not eat stale foo...' -> 'बासी भोजन व सड़क किन...'>
# <AlignedSent: 'Do not feed children...' -> 'बच्चों को फास्ट फूड ...'>
# <AlignedSent: 'In case of vomiting ...' -> 'कै-दस्त होने पर नमक ...'>
# <AlignedSent: 'Drink pure water as ...' -> 'साफ पानी अधिक से अधि...'>
# <AlignedSent: 'I suffer from fever ...' -> 'लगातार बुखार से पीड़ि...'>
# <AlignedSent: 'Kalajar , Malaria or...' -> 'कालाजार , मलेरिया या...'>
# <AlignedSent: 'My child is sufferin...' -> 'मेरा बच्चा दस्त और ब...'>
# <AlignedSent: 'First feed the mixtu...' -> 'पहले ओ.आर.एस. का घोल...'>
# <AlignedSent: 'Fever occurs at an i...' -> 'ढाई - तीन वर्षो से ह...'>
# <AlignedSent: 'Not only this . whit...' -> 'यही नहीं जीभ पर सफेद...'>
# <AlignedSent: 'Drink plenty of wate...' -> 'पानी की मात्रा ज्याद...'>
# <AlignedSent: 'What are the primary...' -> 'कालाजार के प्रारंभिक...'>
# <AlignedSent: 'I have light fever f...' -> 'कुछ दिनों से हल्का फ...'>
# <AlignedSent: 'Get the fever checke...' -> 'बुखार की जाँच करें औ...'>
# <AlignedSent: 'Fever goes down afte...' -> 'मेटासिन की गोली देने...'>
# <AlignedSent: 'X-ray and TC-DC are ...' -> 'एक्सरे , टीसी-डीसी न...'>
# <AlignedSent: 'Measure the fever ev...' -> 'चार - चार घंटे पर फी...'>
# <AlignedSent: 'If fever is more the...' -> 'अगर 100 से ज्यादा फी...'>
# <AlignedSent: 'What is H . . ....' -> 'एच.आई.वी. क्या है ?...'>
# <AlignedSent: 'How does it happens ...' -> 'यह कैसे होता है ?RD_...'>
# <AlignedSent: 'State the solutions ...' -> 'बचाव के उपाय बताएँ ?...'>
# <AlignedSent: 'This is a kind of vi...' -> 'यह एक प्रकार का वायर...'>
# <AlignedSent: 'Its spread occurs ma...' -> 'इसका फैलाव मुख्यत: अ...'>
# <AlignedSent: 'The disease immune c...' -> 'इससे शरीर की रोग प्र...'>
# <AlignedSent: 'What is the identifi...' -> 'बोन टीवी की क्या पहच...'>
# <AlignedSent: 'Pain in the bones , ...' -> 'हड्डियों में दर्द , ...'>
# <AlignedSent: 'Bones become weak an...' -> 'इससे हड्डियाँ कमजोर ...'>
# <AlignedSent: 'Paralysis may also a...' -> 'इस परिस्थिति में लकव...'>
# <AlignedSent: 'To test it do digita...' -> 'इसकी जाँच के लिए डिज...'>
# <AlignedSent: 'Keep a shawl necessa...' -> 'रात में सोते समय शरी...'>
# <AlignedSent: 'If you do not feel c...' -> 'इससे अगर अपने आप सही...'>
# <AlignedSent: 'Children are sufferi...' -> 'बच्चों को घमौंरी हो ...'>
# <AlignedSent: 'What is the home tre...' -> 'डायरिया का घरेलू उपच...'>
# <AlignedSent: 'Put two spoons of su...' -> 'एक गिलास पानी में दो...'>
# <AlignedSent: 'Does kalajar occur b...' -> 'धूप के कारण क्या काल...'>
# <AlignedSent: 'Does its influence i...' -> 'क्या गर्मी में इसका ...'>
# <AlignedSent: 'Kalajar is caused by...' -> 'कालाजार बालू मक्खी क...'>
# <AlignedSent: 'Its treatment is ava...' -> 'इसका उपचार सभी अस्पत...'>
# <AlignedSent: 'There is a tablet al...' -> 'इसके लिए अब टेबलेट भ...'>
# <AlignedSent: 'What should be done ...' -> 'किसी बच्चे को कुकुर ...'>
# <AlignedSent: 'Administer the DPT v...' -> 'बच्चे को डीपीटी का ट...'>
# <AlignedSent: 'Get consulted with a...' -> 'किसी विशेषज्ञ चिकित्...'>
# <AlignedSent: 'How much aware are y...' -> 'अपनी आँखों की देखभाल...'>
# <AlignedSent: 'Get eyes checked up ...' -> 'हर छह माह में करें आ...'>
# <AlignedSent: 'Maintain the glass o...' -> 'चश्मे या कांटैक्ट ले...'>
# <AlignedSent: 'Washing eyes regular...' -> 'नियमित आँखें धोना ।...'>
# <AlignedSent: 'But along with all t...' -> 'लेकिन इन सबके साथ अग...'>
# <AlignedSent: 'not only the vision ...' -> 'तो न सिर्फ आपकी आँखो...'>
# <AlignedSent: 'But this twin otter ...' -> 'लेकिन 12 - 15 सीटों ...'>
# <AlignedSent: 'One does n't come to...' -> 'पानी की सतह पर स्पीड...'>
# <AlignedSent: 'In the entire flight...' -> 'पूरी उड़ान में आपको आ...'>
# <AlignedSent: 'All the time your ey...' -> 'हर वक्‍त आपकी निगाहे...'>
# <AlignedSent: 'Everything is visibl...' -> 'सब कुछ कितना साफ दिख...'>
# <AlignedSent: 'There are only two s...' -> 'मालदीव में दो ही सी ...'>
# <AlignedSent: 'Trans Maldivian is o...' -> 'ट्राँस मालदीवियन इन्...'>
# <AlignedSent: 'If you want then in ...' -> 'आप चाहें तो लगभग चार...'>
# <AlignedSent: 'If you go to some ot...' -> 'वैसे अगर आप माले द्व...'>
# <AlignedSent: 'And that is one such...' -> 'और वो एक ऐसा सफर होत...'>
# <AlignedSent: 'Sea plane do journey...' -> 'सी प्लेन 12 किलोमीटर...'>
# <AlignedSent: 'We were in the large...' -> 'हम माले के अहमदी बाज...'>
# <AlignedSent: 'All salesmen were li...' -> 'सारे सेल्समैन मालदीव...'>
# <AlignedSent: 'If I say with honest...' -> 'ईमानदारी से कहूँ तो ...'>
# <AlignedSent: 'But when there is a ...' -> 'लेकिन जब इस धरती की ...'>
# <AlignedSent: 'many people might ha...' -> 'कई लोगों ने अक्टूबर ...'>
# <AlignedSent: 'Something as special...' -> 'वहाँ की सुंदरता में ...'>
# <AlignedSent: 'As if so much of bea...' -> 'उस छोटे से देश में म...'>
# <AlignedSent: 'While returning towa...' -> 'बाजार की उस सैर से व...'>
# <AlignedSent: 'The water was so cle...' -> 'पानी इतना साफ था कि ...'>
# <AlignedSent: 'This was that part o...' -> 'यह समंदर का वो हिस्स...'>
# <AlignedSent: 'If you are able to s...' -> 'आप भारत के किसी शहर ...'>
# <AlignedSent: 'While returning to M...' -> 'एमवी एक्वामैरिन पर ल...'>
# <AlignedSent: 'Coral reef is the li...' -> 'कोरल रीफ ( मूँगा चट्...'>
# <AlignedSent: 'To this point that y...' -> 'यहाँ तक की आपको कब्र...'>
# <AlignedSent: 'A little while befor...' -> 'राष्‍ट्रपति नाशीद का...'>
# <AlignedSent: 'Could not believe th...' -> 'यकीन नहीं होता था कि...'>
# <AlignedSent: 'With much pleasure w...' -> 'मजे से हम उसके बंगले...'>
# <AlignedSent: 'Can you think of thi...' -> 'क्या आप भारत में किस...'>
# <AlignedSent: 'Got to know this as ...' -> 'पता तो यह भी चला कि ...'>
# <AlignedSent: 'Every thing about Ma...' -> 'मालदीव के बारे में ह...'>
# <AlignedSent: 'This is why I was wa...' -> 'इसीलिए मुझे अगले दिन...'>
# <AlignedSent: 'There was a hunch th...' -> 'इल्हाम था कि वह दिन ...'>
# <AlignedSent: 'In the morning one b...' -> 'सवेरे क्रूज से एक ना...'>
# <AlignedSent: 'From there while cir...' -> 'वहाँ से हम रनवे का च...'>
# <AlignedSent: 'Last evening when cr...' -> 'पिछली शाम जब क्रूज म...'>
# <AlignedSent: 'We had seen so many ...' -> 'इतनी तस्वीरें जो देख...'>
# <AlignedSent: 'But then there was n...' -> 'लेकिन तब गुमान न था ...'>
# <AlignedSent: 'We were to go to one...' -> 'ट्रॉस मालदीवियन के स...'>
# <AlignedSent: 'To see thousands of ...' -> 'लगभग हजार मीटर की ऊँ...'>
# <AlignedSent: 'This beauty of water...' -> 'पानी की यह खूबसूरती ...'>
# <AlignedSent: 'That flight was a br...' -> 'रोमांच व उत्साह से स...'>
# <AlignedSent: 'But on reaching Conr...' -> 'लेकिन रंगाली द्वीप प...'>
# <AlignedSent: 'In such a world that...' -> 'ऐसी दुनिया में , जिस...'>
# <AlignedSent: 'Association was also...' -> 'वास्ता इस तरह भी नही...'>
# <AlignedSent: 'Sauntering on Conrad...' -> 'कोनराड पर सैर पैदल भ...'>
# <AlignedSent: 'While going on to th...' -> 'जेट्‍टी से मुख्य द्व...'>
# <AlignedSent: 'We had not even been...' -> 'अभी हम आस-पास की प्र...'>
# <AlignedSent: 'While descending dow...' -> 'सीढ़ियों से कई मीटर न...'>
# <AlignedSent: 'This room was actual...' -> 'वह कमरा दरअसल एक डाइ...'>
# <AlignedSent: 'All around across gl...' -> 'सब तरफ शीशों के पार ...'>
# <AlignedSent: 'The imagination of e...' -> 'वहाँ सजी मेजों पर बै...'>
# <AlignedSent: 'The fare on coming t...' -> 'माले से सी प्लेन में...'>
# <AlignedSent: 'there was no wish to...' -> 'वहाँ से लौटने का मन ...'>
# <AlignedSent: 'We were ready to flo...' -> 'हम लोग अपने पासपोर्ट...'>
# <AlignedSent: 'But knew it was not ...' -> 'लेकिन जानते थे , यह ...'>
# <AlignedSent: 'With heavy heart we ...' -> 'भारी मन से इसी उम्मी...'>
# <AlignedSent: 'Were making a plan t...' -> 'कई दिनों से दिल्ली स...'>
# <AlignedSent: 'Since childhood had ...' -> 'बचपन से वाइल्ड लाइफ ...'>
# <AlignedSent: 'After biking till Pe...' -> '2006 में लद्दाख में ...'>
# <AlignedSent: 'On the morning of 27...' -> '27 दिसंबर की तड़के हम...'>
# <AlignedSent: 'The journey between ...' -> 'हापुड़ से गजरौला के ब...'>
# <AlignedSent: 'On top of this fog a...' -> 'ऊपर से कोहरा और सामन...'>
# <AlignedSent: 'Many a time it felt ...' -> 'कई बार तो लगा कि अब ...'>
# <AlignedSent: 'Somehow reached Gajr...' -> 'किसी तरह सुबह 8 बजे ...'>
# <AlignedSent: 'Anyway we reached Ra...' -> 'खैर हम 12 बजे रामनगर...'>
# <AlignedSent: 'Corbett park is 20 k...' -> 'कार्बेट पार्क रामनगर...'>
# <AlignedSent: 'Our resort was in Dh...' -> 'हमारा रिजॉर्ट पार्क ...'>
# <AlignedSent: 'That day there was n...' -> 'उस दिन कुछ खास कार्य...'>
# <AlignedSent: 'After spending two -...' -> 'दो - तीन घंटे वहाँ ब...'>
# <AlignedSent: 'From there we went t...' -> 'वहाँ से हम नीचे रामन...'>
# <AlignedSent: 'While returning it b...' -> 'लौटते देर शाम हो गई ...'>
# <AlignedSent: 'I had left delhi aft...' -> 'दिल्ली से ठान कर निक...'>
# <AlignedSent: 'In the middle of the...' -> 'रात की गहराइयों के ब...'>
# <AlignedSent: 'Therefore came the a...' -> 'लिहाजा पहले कालाढुंग...'>
# <AlignedSent: 'Kaladhungi is thirty...' -> 'कालाढुंगी तीस किमी द...'>
# <AlignedSent: 'In Kaladhungi there ...' -> 'कालाढुंगी में जिम का...'>
# <AlignedSent: 'It struck half past ...' -> 'लौटते-लौटते साढ़े बार...'>
# <AlignedSent: 'Kaladhungi is an ext...' -> 'कालाढुंगी बेहद खूबसू...'>
# <AlignedSent: 'On reaching Resort s...' -> 'रिजॉर्ट पहुँचने पर स...'>
# <AlignedSent: 'It was told that fac...' -> 'बताया गया कि उन्होंन...'>
# <AlignedSent: 'On asking about numb...' -> 'नंबर एक के बारे में ...'>
# <AlignedSent: 'We were given a guid...' -> 'बिजरानी पहुँचते ही ह...'>
# <AlignedSent: 'We set out for fores...' -> 'हम अंदर जंगल के लिए ...'>
# <AlignedSent: 'There we saw animals...' -> 'हमने वहाँ कई तरह के ...'>
# <AlignedSent: 'We saw two tusker el...' -> 'अंदर हमने दो टस्कर ह...'>
# <AlignedSent: 'I photographed profu...' -> 'मैंने जमकर फोटोग्राफ...'>
# <AlignedSent: 'Amidst all this the ...' -> 'इस बीच गाइड ने टाइगर...'>
# <AlignedSent: 'Guide told us that t...' -> 'गाइड ने बताया कि पार...'>
# <AlignedSent: 'At many places we sa...' -> 'कई जगह हमें उनके पंज...'>
# <AlignedSent: 'Third day we had to ...' -> 'तीसरे दिन हमें दिल्ल...'>
# <AlignedSent: 'In my brain the furo...' -> 'मेरे दिमाग में तो टा...'>
# <AlignedSent: 'Suddenly then I reme...' -> 'तभी मुझे हल्द्वानी क...'>
# <AlignedSent: 'I called him just li...' -> 'मैंने उसे ऐसे ही फोन...'>
# <AlignedSent: 'I told him that I ha...' -> 'मैंने उसे बताया कि म...'>
# <AlignedSent: 'He asked you saw tig...' -> 'उसने पूछा टाइगर देखा...'>
# <AlignedSent: 'These words pricked ...' -> 'उसके यह शब्द तीर की ...'>
# <AlignedSent: 'I slowly said no ....' -> 'मैंने धीरे से कहा , ...'>
# <AlignedSent: 'There was no permiss...' -> 'पार्क में बाइक ले जा...'>
# <AlignedSent: 'Somebody advised us ...' -> 'हमें किसी ने सलाह दी...'>

# %%
test_sentence = bitext[112]
print(test_sentence.words)
print(test_sentence.mots)
print(test_sentence.alignment)
# Out:
# ['All', 'salesmen', 'were', 'listening', 'carefully', 'the', 'speech', 'given', 'by', 'president', 'Mohammad', 'Nasheed', 'in', 'World', 'climate', 'conference', 'a', 'day', 'before', 'in', 'Copenhagen', '.']
# ['सारे', 'सेल्समैन', 'मालदीव', 'के', 'राष्\u200dट्रपति', 'मोहम्मद', 'नाशीद', 'द्वारा', 'एक', 'दिन', 'पहले', 'कोपेनहेगन', 'में', 'विश्\u200dव', 'जलवायु', 'सम्मेलन', 'में', 'दिए', 'गए', 'भाषण', 'को', 'बड़े', 'ध्यान', 'से', 'सुन', 'रहे', 'थे', '।']
# 0-24 1-24 2-26 3-19 4-22 5-3 6-19 7-17 8-7 9-19 10-24 11-19 12-16 13-24 14-24 15-24 16-25 17-9 18-10 19-16 20-24 21-27

# %%
# bitext.append(AlignedSent(['what is Education'], ['शिक्षा क्या है']))

# %%
ibm1 = IBMModel1(bitext, 15)

# %%
print(ibm1.translation_table['what']['क्या'])
# Out:
# 0.10344207667425154

# %%
for i in bitext:
  print(i.words)
  print(i.mots)
# Out:
# ['Fresh', 'breath', 'and', 'shining', 'teeth', 'enhance', 'your', 'personality', '.']
# ['ताजा', 'साँसें', 'और', 'चमचमाते', 'दाँत', 'आपके', 'व्यक्तित्व', 'को', 'निखारते', 'हैं', '।']
# ['Your', 'self-confidence', 'also', 'increases', 'with', 'teeth', '.']
# ['दाँतों', 'से', 'आपका', 'आत्मविश्\u200dवास', 'भी', 'बढ़ता', 'है', '।']
# ['Bacteria', 'stay', 'between', 'our', 'gums', 'and', 'teeth', '.']
# ['हमारे', 'मसूढ़ों', 'और', 'दाँतों', 'के', 'बीच', 'बैक्टीरिया', 'मौजूद', 'होते', 'हैं', '।']
# ['They', 'make', 'teeth', 'dirty', 'and', 'breath', 'stinky', '.']
# ['ये', 'दाँतों', 'को', 'गंदा', 'और', 'साँसों', 'को', 'बदबूदार', 'बना', 'देते', 'हैं', '।']
# ['You', 'may', 'keep', 'your', 'teeth', 'clean', 'and', 'breath', 'fresh', 'by', 'the', 'help', 'of', 'some', 'easy', 'tips', 'given', 'here', '.']
# ['यहाँ', 'दिए', 'कुछ', 'आसान', 'नुस्खों', 'की', 'मदद', 'से', 'आप', 'अपने', 'दाँतों', 'को', 'स्वच्छ', 'और', 'साँसों', 'को', 'ताजा', 'रख', 'सकते', 'हैं', '।']
# ['Clean', 'your', 'teeth', 'properly', '.']
# ['दाँतों', 'को', 'ठीक', 'से', 'साफ', 'करें', '।']
# ['It', 'takes', 'two', 'to', 'three', 'minutes', 'to', 'clean', 'your', 'teeth', 'properly', '.']
# ['दाँतों', 'को', 'ठीक', 'से', 'साफ', 'करने', 'में', 'दो', 'से', 'तीन', 'मिनट', 'का', 'समय', 'लगता', 'है', '।']
# ['But', 'most', 'of', 'the', 'people', 'give', 'less', 'than', 'one', 'minute', 'for', 'this', '.']
# ['लेकिन', 'ज्यादातर', 'लोग', 'इसके', 'लिए', 'एक', 'मिनट', 'से', 'भी', 'कम', 'समय', 'देते', 'हैं', '।']
# ['Drink', 'plenty', 'of', 'water', '.']
# ['खूब', 'पानी', 'पीएँ', '।']
# ['Bacteria', 'attack', 'fast', 'if', 'the', 'mouth', 'dries', 'up', '.']
# ['मुँह', 'सूखने', 'पर', 'बैक्टीरिया', 'हमला', 'तेज', 'कर', 'देते', 'हैं', '।']
# ['With', 'this', 'stink', 'comes', 'from', 'breath', '.']
# ['इससे', 'साँसों', 'से', 'बदबू', 'आने', 'लगती', 'है', '।']
# ['By', 'drinking', 'plenty', 'of', 'water', 'not', 'only', 'the', 'left-over', 'pieces', 'of', 'food', 'gets', 'cleaned', 'but', 'saliva', 'also', 'gets', 'formed', '.']
# ['खूब', 'पानी', 'पीने', 'से', 'न', 'केवल', 'खाने', 'के', 'बचे', '-', 'खुचे', 'टुकड़े', 'साफ', 'हो', 'जाते', 'हैं', ',', 'बल्कि', 'लार', 'भी', 'बनती', 'है', '।']
# ['Saliva', 'has', 'important', 'role', 'in', 'keeping', 'the', 'mouth', 'clean', '.']
# ['मुँह', 'साफ', 'रखने', 'में', 'लार', 'की', 'खास', 'भूमिका', 'होती', 'है', '।']
# ['Saliva', 'destroys', 'those', 'bacteria', 'which', 'create', 'stink', 'in', 'breath', '.']
# ['लार', 'उन', 'बैक्टीरिया', 'को', 'नष्ट', 'करती', 'है', 'जो', 'साँसों', 'में', 'बदबू', 'पैदा', 'करते', 'हैं', '।']
# ['Chew', 'the', 'sugar-free', 'chewing', 'gum', '.']
# ['चबाएँ', 'शुगर', 'रहित', 'चुइंग', 'गम', '।']
# ['Saliva', 'is', 'formed', 'by', 'chewing', 'the', 'chewing', 'gum', '.']
# ['चुइंग', 'गम', 'चबाने', 'से', 'लार', 'बनती', 'है', '।']
# ['Chewing', 'gum', 'helps', 'in', 'keeping', 'the', 'teeth', 'clean', '.']
# ['चुइंग', 'गम', 'से', 'दाँतों', 'को', 'साफ', 'रखने', 'में', 'मदद', 'मिलती', 'है', '।']
# ['Sugared', 'chewing', 'gum', 'is', 'not', 'supposed', 'to', 'be', 'good', 'for', 'health', '.']
# ['शुगर', 'युक्त', 'गम', 'को', 'सेहत', 'के', 'लिए', 'अच्छा', 'नहीं', 'माना', 'जाता', '।']
# ['That', 'is', 'why', 'dentists', 'do', 'not', 'suggest', 'chewing', 'sugared', 'chewing', 'gum', '.']
# ['इसलिए', 'डेंटिस्ट', 'शुगर', 'युक्त', 'गम', 'को', 'खाने', 'की', 'सलाह', 'नहीं', 'देते', '।']
# ['Get', 'the', 'teeth', 'checked-up', 'regularly', '.']
# ['नियमित', 'रूप', 'से', 'कराएँ', 'दाँतों', 'की', 'जाँच', '।']
# ['Get', 'the', 'teeth', 'checked-up', 'with', 'the', 'dentists', 'regularly', '.']
# ['दंतचिकित्सक', 'से', 'दाँतों', 'की', 'जाँच', 'नियमित', 'रूप', 'से', 'कराएँ', '।']
# ['They', 'solve', 'small', 'problems', 'of', 'the', 'teeth', 'easily', '.']
# ['वे', 'दाँतों', 'की', 'छोटी', '-', 'मोटी', 'समस्या', 'को', 'आसानी', 'से', 'सुलझा', 'देते', 'हैं', '।']
# ['Clean', 'the', 'mouth', 'after', 'meal', '.']
# ['खाने', 'के', 'बाद', 'मुँह', 'साफ', 'करें', '।']
# ['Do', 'clean', 'the', 'mouth', 'every', 'time', 'with', 'water', 'after', 'eating', '.']
# ['हर', 'बार', 'खाने', 'के', 'बाद', 'पानी', 'से', 'मुँह', 'जरूर', 'साफ', 'करें', '।']
# ['The', 'left-over', 'pieces', 'of', 'food', 'is', 'cleaned', 'by', 'it', '.']
# ['इससे', 'खाने', 'के', 'बचे', 'हुए', 'टुकड़े', 'साफ', 'हो', 'जाते', 'हैं', '।']
# ['Clean', 'the', 'teeth', 'with', 'the', 'mixture', 'of', 'lemon', 'and', 'salt', '.']
# ['नींबू', 'और', 'नमक', 'के', 'मिश्रण', 'से', 'दाँत', 'साफ', 'करें', '।']
# ['Taking', 'a', 'spoon', 'of', 'salt', 'pour', 'three', 'to', 'four', 'drops', 'of', 'lemon', 'juice', 'in', 'that', '.']
# ['एक', 'चम्मच', 'में', 'नमक', 'लेकर', 'उसमें', 'तीन', 'से', 'चार', 'बूंदें', 'नींबू', 'की', 'डाल', 'लें', '।']
# ['Clean', 'the', 'teeth', 'every', 'week', 'with', 'this', 'mixture', '.']
# ['हर', 'हफ्ते', 'इस', 'मिश्रण', 'से', 'दाँतों', 'को', 'साफ', 'करें', '।']
# ['Not', 'only', 'teeth', 'starts', 'shining', 'with', 'this', '.']
# ['इससे', 'न', 'केवल', 'दाँत', 'चमचमाने', 'लगते', 'हैं', '।']
# ['But', 'one', 'also', 'gets', 'relief', 'from', 'stinking', 'breath', '.']
# ['बल्कि', 'साँसों', 'की', 'दुर्गंध', 'से', 'भी', 'छुटकारा', 'मिलता', 'है', '।']
# ['If', 'there', 'is', 'health', 'there', 'is', 'everything', '.']
# ['सेहत', 'है', 'तो', 'सब', 'है', '।']
# ['It', 'is', 'not', 'less', 'than', 'a', 'challenge', 'to', 'keep', 'oneself', 'healthy', 'in', 'today', "'s", 'busy', 'life', '.']
# ['आज', 'की', 'व्यस्त', 'जिंदगी', 'में', 'खुद', 'को', 'स्वस्थ', 'रखना', 'किसी', 'चुनौती', 'से', 'कम', 'नहीं', '।']
# ['But', 'you', 'can', 'keep', 'yourself', 'healthy', 'by', 'paying', 'attention', 'to', 'your', 'food', 'habits', 'and', 'by', 'bringing', 'a', 'little', 'change', 'in', 'your', 'lifestyle', '.']
# ['लेकिन', 'खान-पान', 'पर', 'ध्यान', 'और', 'जीवनशैली', 'में', 'थोड़ा', 'बदलाव', 'लाकर', 'आप', 'खुद', 'को', 'स्वस्थ', 'रख', 'सकते', 'हैं', '।']
# ['Eat', 'less', 'fatty', 'food', '.']
# ['कम', 'वसायुक्त', 'आहार', 'का', 'करें', 'सेवन', '।']
# ['Eat', 'only', 'that', 'food', 'in', 'which', 'there', 'is', 'less', 'fat', 'and', 'more', 'fiber', '.']
# ['खाना', 'वही', 'खाएँ', 'जिसमें', 'कम', 'वसा', 'और', 'फाइबर', 'ज्यादा', 'हो', '।']
# ['Fruits', 'and', 'vegetables', 'have', 'a', 'ratio', 'like', 'this', '.']
# ['फलों', 'और', 'सब्जियों', 'में', 'ऐसा', 'ही', 'अनुपात', 'रहता', 'है', '।']
# ['We', 'get', 'helped', 'in', 'controlling', 'our', 'weight', 'by', 'taking', 'less', 'fatty', 'and', 'fibered', 'food', '.']
# ['कम', 'वसा', 'और', 'फाइबर', 'वाले', 'खाने', 'से', 'वजन', 'नियंत्रित', 'करने', 'में', 'मदद', 'मिलती', 'है', '।']
# ['You', 'keep', 'yourself', 'far', 'from', 'many', 'diseases', 'by', 'eating', 'less', 'fatty', 'and', 'fibered', 'food', '.']
# ['कम', 'वसा', 'और', 'फाइबर', 'वाले', 'खाने', 'से', 'आप', 'कई', 'बीमारियों', 'से', 'भी', 'दूर', 'रहते', 'हैं', '।']
# ['Take', 'less', 'salt', 'and', 'alcohol', '.']
# ['नमक', 'और', 'शराब', 'का', 'सेवन', 'कम', 'करें', '।']
# ['Take', 'the', 'least', 'quantity', 'of', 'salt', 'and', 'alcohol', 'to', 'control', 'blood', 'pressure', 'and', 'cholesterol', '.']
# ['ब्लड', 'प्रेशर', 'और', 'कोलेस्ट्राल', 'को', 'नियंत्रित', 'करने', 'के', 'लिए', 'नमक', 'और', 'शराब', 'का', 'सेवन', 'कम', 'से', 'कम', 'मात्रा', 'में', 'करें', '।']
# ['Stop', 'smoking', '.']
# ['बंद', 'करें', 'धूम्रपान', '।']
# ['There', 'is', 'a', 'danger', 'of', 'several', 'diseases', 'including', 'cancer', 'with', 'smoking', '.']
# ['धूम्रपान', 'करने', 'से', 'कैंसर', 'समेत', 'कई', 'बीमारियों', 'का', 'खतरा', 'होता', 'है', '।']
# ['Try', 'your', 'best', 'to', 'quit', 'it', '.']
# ['इसे', 'छोड़ने', 'की', 'पूरी', 'कोशिश', 'करें', '।']
# ['Exercise', 'daily', '.']
# ['रोज', 'करें', 'व्यायाम', '।']
# ['You', 'must', 'include', 'exercise', 'in', 'your', 'daily', 'routine', '.']
# ['अपनी', 'रोज', 'की', 'दिनचर्या', 'में', 'व्यायाम', 'को', 'जरूर', 'शामिल', 'करें', '।']
# ['You', 'can', 'prevent', 'heart', 'diseases', ',', 'colon', 'cancer', ',', 'blood', 'pressure', 'and', 'diabetes', 'like', 'diseases', 'by', 'regular', 'exercise', '.']
# ['नियमित', 'व्यायाम', 'से', 'आप', 'हृदय', 'रोग', ',', 'कोलन', 'कैंसर', ',', 'ब्लड', 'प्रेशर', 'और', 'डायबिटीज', 'जैसी', 'बीमारियों', 'से', 'बचाव', 'कर', 'सकते', 'हैं', '।']
# ['Keep', 'doing', 'light', 'physical', 'activities', '.']
# ['करते', 'रहें', 'हल्की', '-', 'फुल्की', 'शारीरिक', 'गतिविधियाँ', '।']
# ['Keep', 'doing', 'small', 'physical', 'activities', 'like', 'climbing', 'stairs', ',', 'gardening', ',', 'small', 'domestic', 'works', 'or', 'dancing', '.']
# ['सीढ़ी', 'चढ़ना', ',', 'बागवानी', ',', 'घर', 'के', 'छोटे', '-', 'मोटे', 'काम', 'या', 'डांस', 'करने', 'जैसी', 'हल्की', '-', 'फुल्की', 'शारीरिक', 'गतिविधियाँ', 'जरूर', 'करते', 'रहें', '।']
# ['These', 'retain', 'the', 'flexibility', 'in', 'the', 'body', '.']
# ['इनसे', 'शरीर', 'में', 'लचीलापन', 'बना', 'रहता', 'है', '।']
# ['If', 'fever', 'comes', 'continuously', 'you', 'must', 'get', 'it', 'checked', 'up', '.']
# ['यदि', 'लगातार', 'बुखार', 'आ', 'रहा', 'है', 'तो', 'उसकी', 'जाँच', 'अवश्य', 'करायें', '।']
# ['Malaria', ',', 'kalajar', ',', 'tuberculoses', 'starts', 'with', 'fever', '.']
# ['मलेरिया', ',', 'कालाजार', ',', 'यक्ष्मा', 'की', 'शुरुआत', 'बुखार', 'से', 'ही', 'होती', 'है', '।']
# ['Summer', 'season', 'has', 'started', '.']
# ['गर्मी', 'का', 'मौसम', 'शुरू', 'हो', 'चुका', 'है', '।']
# ['Do', 'not', 'eat', 'stale', 'food', 'and', 'the', 'things', 'being', 'sold', 'at', 'road', 'sides', '.']
# ['बासी', 'भोजन', 'व', 'सड़क', 'किनारे', 'बिकने', 'वाले', 'सामान', 'का', 'सेवन', 'नहीं', 'करें', '।']
# ['Do', 'not', 'feed', 'children', 'fast', 'food', ',', 'kurkure', ',', 'ice-cream', '.']
# ['बच्चों', 'को', 'फास्ट', 'फूड', ',', 'कुरकुरे', ',', 'आइसक्रीम', 'नहीं', 'खिलायें', '।']
# ['In', 'case', 'of', 'vomiting', 'and', 'loose-motion', 'feed', 'the', 'O', '.', '.', '.', 'or', 'mixture', 'of', 'salt', 'and', 'sugar', '.']
# ['कै-दस्त', 'होने', 'पर', 'नमक', 'और', 'चीनी', 'का', 'घोल', 'या', 'ओ.आर.एस', 'पिलायें', '।']
# ['Drink', 'pure', 'water', 'as', 'much', 'as', 'you', 'can', '.']
# ['साफ', 'पानी', 'अधिक', 'से', 'अधिक', 'पीयें', '।']
# ['I', 'suffer', 'from', 'fever', 'continuously', '.']
# ['लगातार', 'बुखार', 'से', 'पीड़ित', 'हो', '?']
# ['Kalajar', ',', 'Malaria', 'or', 'high', 'fiver', 'may', 'have', 'happened', '.']
# ['कालाजार', ',', 'मलेरिया', 'या', 'फिर', 'हाई', 'फीवर', 'हो', 'सकता', 'है', '।']
# ['My', 'child', 'is', 'suffering', 'from', 'both', 'diarrhoea', 'and', 'malaria', '.']
# ['मेरा', 'बच्चा', 'दस्त', 'और', 'बुखार', 'दोनों', 'पीड़ित', 'है', '?']
# ['First', 'feed', 'the', 'mixture', 'of', 'O', '.', '.', '.', 'after', 'this', 'get', 'the', 'child', 'checked-up', 'with', 'a', 'paediatrician', '.']
# ['पहले', 'ओ.आर.एस.', 'का', 'घोल', 'पिलायें', ',', 'इसके', 'बाद', 'बच्चे', 'को', 'किसी', 'शिशु', 'रोग', 'विशेषज्ञ', 'से', 'शीघ्र', 'दिखायें', '।']
# ['Fever', 'occurs', 'at', 'an', 'interval', 'of', 'two', 'to', 'three', 'months', 'since', 'two', 'and', 'half', 'to', 'three', 'years', '.']
# ['ढाई', '-', 'तीन', 'वर्षो', 'से', 'हर', 'दो', '-', 'तीन', 'माह', 'पर', 'फीवर', 'हो', 'जाता', 'है', '।']
# ['Not', 'only', 'this', '.', 'white', 'coat', 'also', 'forms', 'on', 'tongue', '.']
# ['यही', 'नहीं', 'जीभ', 'पर', 'सफेद', 'परत', 'जम', 'जाती', 'है', '।']
# ['Drink', 'plenty', 'of', 'water', 'and', 'get', 'urine', 'culture', 'done', '.']
# ['पानी', 'की', 'मात्रा', 'ज्यादा', 'लें', 'और', 'यूरीन', 'कल्चर', 'जाँच', 'करायें', '।']
# ['What', 'are', 'the', 'primary', 'symptoms', 'of', 'kalajar', '.']
# ['कालाजार', 'के', 'प्रारंभिक', 'लक्षण', 'क्या', 'हैं', '?RD_PUNC']
# ['I', 'have', 'light', 'fever', 'for', 'some', 'days', '.']
# ['कुछ', 'दिनों', 'से', 'हल्का', 'फीवर', 'रहता', 'है', '।']
# ['Get', 'the', 'fever', 'checked', 'up', 'and', 'only', 'after', 'the', 'other', 'essential', 'tests', 'kalajar', 'can', 'be', 'verified', '.']
# ['बुखार', 'की', 'जाँच', 'करें', 'और', 'अन्य', 'जरूरी', 'जाँच', 'के', 'पश्चात', 'ही', 'कालाजार', 'प्रमाणित', 'हो', 'सकता', 'है', '।']
# ['Fever', 'goes', 'down', 'after', 'taking', 'the', 'tablet', 'of', 'Metacin', 'and', 'again', 'fever', 'increases', 'up', 'to', '103', '.']
# ['मेटासिन', 'की', 'गोली', 'देने', 'से', 'बुखार', 'उतर', 'जाता', 'है', 'और', 'फिर', '103', 'तक', 'बुखार', 'चढ़', 'जाता', 'है', '।']
# ['X-ray', 'and', 'TC-DC', 'are', 'normal', '.']
# ['एक्सरे', ',', 'टीसी-डीसी', 'नार्मल', 'है', '।']
# ['Measure', 'the', 'fever', 'every', 'four', 'hours', '.']
# ['चार', '-', 'चार', 'घंटे', 'पर', 'फीवर', 'को', 'मापें', '।']
# ['If', 'fever', 'is', 'more', 'then', '100', 'give', 'a', 'pill', 'of', 'paracetamol', 'and', 'take', 'suggestions', 'from', 'a', 'medicine', 'specialist', 'doctor', '.']
# ['अगर', '100', 'से', 'ज्यादा', 'फीवर', 'हो', 'तो', 'पैरासीटामोल', 'की', 'गोली', 'दें', 'और', 'किसी', 'औषधि', 'विशेषज्ञ', 'चिकित्सक', 'से', 'परामर्श', 'लें', '।']
# ['What', 'is', 'H', '.', '.', '.']
# ['एच.आई.वी.', 'क्या', 'है', '?']
# ['How', 'does', 'it', 'happens', '.']
# ['यह', 'कैसे', 'होता', 'है', '?RD_PUNC']
# ['State', 'the', 'solutions', 'of', 'prevention', '.']
# ['बचाव', 'के', 'उपाय', 'बताएँ', '?']
# ['This', 'is', 'a', 'kind', 'of', 'virus', '.']
# ['यह', 'एक', 'प्रकार', 'का', 'वायरस', 'होता', 'है', '।']
# ['Its', 'spread', 'occurs', 'mainly', 'through', 'unprotected', 'sex', 'relation', ',', 'infected', 'needle', ',', 'infected', 'blood', 'and', 'from', 'mother', 'to', 'children', '.']
# ['इसका', 'फैलाव', 'मुख्यत:', 'असुरक्षित', 'यौन', 'संबंध', ',', 'संक्रमित', 'सूई', ',', 'संक्रमित', 'रक्त', 'व', 'माँ', 'से', 'बच्चों', 'में', 'होता', 'है', '।']
# ['The', 'disease', 'immune', 'capacity', 'of', 'the', 'body', 'keeps', 'on', 'decreasing', 'with', 'this', '.']
# ['इससे', 'शरीर', 'की', 'रोग', 'प्रतिरोधक', 'क्षमता', 'कम', 'होती', 'जाती', 'है', '।']
# ['What', 'is', 'the', 'identification', 'of', 'bone', 'TB', ',', 'and', 'what', 'is', 'its', 'treatment', '.']
# ['बोन', 'टीवी', 'की', 'क्या', 'पहचान', 'है', 'तथा', 'इसका', 'क्या', 'इलाज', 'है', '?']
# ['Pain', 'in', 'the', 'bones', ',', 'continuous', 'fever', ',', 'whether', 'it', 'is', 'low', 'or', 'increasing', 'by', 'the', 'evening', ',', 'deformation', 'of', 'bones', 'along', 'with', 'pain', 'are', 'the', 'symptoms', 'of', 'tuberculosis', '.']
# ['हड्डियों', 'में', 'दर्द', ',', 'लगातार', 'बुखार', ',', 'भले', 'ही', 'यह', 'कम', 'क्यों', 'न', 'हो', 'या', 'बुखार', 'शाम', 'में', 'बढ़', 'जाये', ',', 'दर्द', 'के', 'साथ-साथ', 'हड्डियों', 'में', 'विकृति', 'आ', 'जाये', 'तो', 'यह', 'बोन', 'टीबी', 'का', 'लक्षण', 'है', '।']
# ['Bones', 'become', 'weak', 'and', 'starts', 'melting', '.']
# ['इससे', 'हड्डियाँ', 'कमजोर', 'हो', 'जाती', 'हैं', 'और', 'गलने', 'लगती', 'हैं', '।']
# ['Paralysis', 'may', 'also', 'attack', 'in', 'this', 'situation', '.']
# ['इस', 'परिस्थिति', 'में', 'लकवा', 'भी', 'मार', 'सकता', 'है', '।']
# ['To', 'test', 'it', 'do', 'digital', 'X-ray', '.', '.', '.', '.', 'take', 'medicine', 'of', 'tuberculosis', 'for', 'a', 'year', 'and', 'consult', 'the', 'specialist', 'doctor', '.']
# ['इसकी', 'जाँच', 'के', 'लिए', 'डिजिटल', 'एक्सरे', ',', 'एम.आर.आई.', 'करायें', ',', 'टीबी', 'की', 'दवा', 'एक', 'वर्ष', 'तक', 'लें', 'एवं', 'विशेषज्ञ', 'चिकित्सक', 'से', 'परामर्श', 'लें', '।']
# ['Keep', 'a', 'shawl', 'necessarily', 'over', 'the', 'body', 'and', 'run', 'the', 'fan', 'to', 'the', 'minimum', 'in', 'the', 'night', 'while', 'sleeping', '.']
# ['रात', 'में', 'सोते', 'समय', 'शरीर', 'पर', 'एक', 'चादर', 'जरूर', 'रखे', 'एवं', 'पंखा', 'कम', 'से', 'कम', 'चलायें', '।']
# ['If', 'you', 'do', 'not', 'feel', 'comfortable', 'with', 'it', 'take', 'anti-allergic', 'tablet', 'for', 'ten', 'days', '.']
# ['इससे', 'अगर', 'अपने', 'आप', 'सही', 'महसूस', 'नहीं', 'करते', 'हैं', 'तो', 'एन्टीएलर्जिक', 'टेबलेट', 'दस', 'दिनों', 'तक', 'लें', '।']
# ['Children', 'are', 'suffering', 'from', 'prickly', 'heat', ',', 'what', 'to', 'do', '.']
# ['बच्चों', 'को', 'घमौंरी', 'हो', 'रही', 'है', 'क्या', 'करें', '?']
# ['What', 'is', 'the', 'home', 'treatment', 'of', 'diarrhoea', '.']
# ['डायरिया', 'का', 'घरेलू', 'उपचार', 'क्या', 'है', '?']
# ['Put', 'two', 'spoons', 'of', 'sugar', 'and', 'a', 'pinch', 'of', 'salt', 'in', 'a', 'glass', 'of', 'water', 'and', 'boil', 'it', '.']
# ['एक', 'गिलास', 'पानी', 'में', 'दो', 'चम्मच', 'चीनी', 'एवं', 'एक', 'चुटकी', 'नमक', 'डालकर', 'उबालकर', 'दें', '।']
# ['Does', 'kalajar', 'occur', 'because', 'of', 'sun', '.']
# ['धूप', 'के', 'कारण', 'क्या', 'कालाजार', 'रोग', 'होता', 'है', '?']
# ['Does', 'its', 'influence', 'increase', 'in', 'summer', '.']
# ['क्या', 'गर्मी', 'में', 'इसका', 'प्रकोप', 'बढ़', 'जाता', 'है', '?']
# ['Kalajar', 'is', 'caused', 'by', 'the', 'sting', 'of', 'sand-fly', '.']
# ['कालाजार', 'बालू', 'मक्खी', 'के', 'काटने', 'से', 'होता', 'है', '।']
# ['Its', 'treatment', 'is', 'available', 'in', 'all', 'the', 'hospitals', '.']
# ['इसका', 'उपचार', 'सभी', 'अस्पतालों', 'में', 'है', '।']
# ['There', 'is', 'a', 'tablet', 'also', 'available', 'for', 'this', 'now', '.']
# ['इसके', 'लिए', 'अब', 'टेबलेट', 'भी', 'उपलब्ध', 'हैं', '।']
# ['What', 'should', 'be', 'done', 'when', 'a', 'child', 'suffers', 'from', 'whooping', 'cough', '.']
# ['किसी', 'बच्चे', 'को', 'कुकुर', 'खाँसी', 'हो', 'जाये', 'तो', 'क्या', 'करना', 'चाहिये', '?']
# ['Administer', 'the', 'DPT', 'vaccine', 'to', 'the', 'child', '.']
# ['बच्चे', 'को', 'डीपीटी', 'का', 'टीका', 'लगायें', '।']
# ['Get', 'consulted', 'with', 'a', 'specialist', 'doctor', 'and', 'get', 'the', 'mucus', 'tested', 'for', 'cough', '.']
# ['किसी', 'विशेषज्ञ', 'चिकित्सक', 'से', 'दिखायें', 'तथा', 'खाँसी', 'के', 'लिए', 'बलगम', 'की', 'जाँच', 'करायें', '।']
# ['How', 'much', 'aware', 'are', 'you', 'about', 'the', 'care', 'of', 'your', 'eyes', '.']
# ['अपनी', 'आँखों', 'की', 'देखभाल', 'को', 'लेकर', 'आप', 'कितने', 'जागरूक', 'हैं', '?']
# ['Get', 'eyes', 'checked', 'up', 'every', 'six', 'months', '.']
# ['हर', 'छह', 'माह', 'में', 'करें', 'आँखों', 'की', 'जाँच', '।']
# ['Maintain', 'the', 'glass', 'or', 'contact', 'lens', '.']
# ['चश्मे', 'या', 'कांटैक्ट', 'लेंस', 'का', 'रखरखाव', 'करें', '।']
# ['Washing', 'eyes', 'regularly', '.']
# ['नियमित', 'आँखें', 'धोना', '।']
# ['But', 'along', 'with', 'all', 'this', 'if', 'you', 'pay', 'attention', 'to', 'your', 'food-habits', '.']
# ['लेकिन', 'इन', 'सबके', 'साथ', 'अगर', 'आप', 'अपने', 'खान', '-|RD_PUNC', 'पान', 'पर', 'थोड़ा', 'सा', 'ध्यान', 'दें', '।']
# ['not', 'only', 'the', 'vision', 'of', 'your', 'eyes', 'may', 'be', 'better', '.']
# ['तो', 'न', 'सिर्फ', 'आपकी', 'आँखों', 'की', 'रोशनी', 'बेहतर', 'हो', 'सकती', 'है', '।']
# ['But', 'this', 'twin', 'otter', 'plane', 'of', '12', '-', '15', 'seats', 'is', 'undoubtedly', 'the', 'best', 'for', 'sightseeing', 'an', 'archipelago', '-LRB-', 'island', 'group', '-RRB-', 'like', 'Maldives', '.']
# ['लेकिन', '12', '-', '15', 'सीटों', 'वाला', 'यह', 'टिवन', 'ओटर', 'प्लेन', 'मालदीव', 'जैसे', 'आर्कीपेलेगो', '(', 'द्वीप', 'समूह', ')', 'को', 'घूमने', 'के', 'लिए', 'निर्विवाद', 'रूप', 'से', 'श्रेष्\u200dठ', 'है', '।']
# ['One', 'does', "n't", 'come', 'to', 'know', 'when', 'it', 'rise', 'in', 'air', 'while', 'running', 'like', 'speed', 'boat', 'on', 'the', 'surface', 'water', '.']
# ['पानी', 'की', 'सतह', 'पर', 'स्पीड', 'बोट', 'की', 'तरह', 'दौड़ते', 'हुए', 'यह', 'कब', 'हवा', 'में', 'उठ', 'जाता', 'है', ',', 'पता', 'नहीं', 'चलता', '।']
# ['In', 'the', 'entire', 'flight', 'you', 'do', 'not', 'feel', 'the', 'experience', 'of', 'ordinary', 'flights', '.']
# ['पूरी', 'उड़ान', 'में', 'आपको', 'आम', 'हवाई', 'जहाजों', 'की', 'उड़ान', 'का', 'अनुभव', 'नहीं', 'होता', '।']
# ['All', 'the', 'time', 'your', 'eyes', 'keep', 'looking', 'down', 'out', 'of', 'the', 'window', '-', 'gazing', 'at', 'resort', 'islands', 'of', 'Maldives', 'in', 'blue', 'water', 'of', 'different', 'shades', 'and', 'coral', 'islands', '.']
# ['हर', 'वक्\u200dत', 'आपकी', 'निगाहें', 'खिड़की', 'से', 'नीचे', 'को', 'ताकती', 'रहती', 'हैं', '-', 'मालदीव', 'के', 'अलग-अलग', 'शेड्\u200dस', 'के', 'नीले', 'पानी', 'में', 'रिजॉर्ट', 'द्वीपों', 'व', 'कोरल', 'द्वीपों', 'को', 'निहारते', 'हुए', '।']
# ['Everything', 'is', 'visible', 'so', 'clearly', '.']
# ['सब', 'कुछ', 'कितना', 'साफ', 'दिखता', 'है', '।']
# ['There', 'are', 'only', 'two', 'sea', 'plane', 'companies', 'in', 'Maldives', '.']
# ['मालदीव', 'में', 'दो', 'ही', 'सी', 'प्लेन', 'कंपनियाँ', 'हैं', '।']
# ['Trans', 'Maldivian', 'is', 'one', 'of', 'them', 'which', 'has', '20', 'sea', 'planes', '.']
# ['ट्राँस', 'मालदीवियन', 'इन्हीं', 'में', 'से', 'एक', 'है', 'जिसके', 'पास', 'बीस', 'सी', 'प्लेन', 'है', '।']
# ['If', 'you', 'want', 'then', 'in', 'around', 'four', 'thousand', 'rupees', '-LRB-', 'per', 'person', '-RRB-', 'you', 'can', 'do', 'air', 'tour', 'for', 'an', 'hour', 'or', 'can', 'hire', 'a', 'complete', 'sea', 'plane', 'for', 'day', 'long', 'roaming', 'around', '-LRB-', 'only', 'if', 'your', 'pocket', 'is', 'heavy', '-RRB-', '.']
# ['आप', 'चाहें', 'तो', 'लगभग', 'चार', 'हजार', 'रुपये', '(', 'प्रति', 'व्यक्\u200dति', ')', 'में', 'घंटेभर', 'की', 'हवाई', 'सैर', 'कर', 'सकते', 'हैं', 'या', 'फिर', 'पूरा', 'सी', 'प्लेन', 'अपनी', 'दिनभर', 'की', 'तफरीह', 'के', 'लिए', 'किराये', 'पर', 'ले', 'सकते', 'हैं', '(', 'बशर्ते', 'जेब', 'गहरी', 'हो', ')', '।']
# ['If', 'you', 'go', 'to', 'some', 'other', 'island', 'separate', 'from', 'Malé', 'island', 'then', 'journey', 'of', 'sea', 'plane', 'would', 'be', 'important', 'this', 'is', 'the', 'only', 'mode', 'of', 'journey', 'amidst', 'various', 'islands', '.']
# ['वैसे', 'अगर', 'आप', 'माले', 'द्वीप', 'से', 'परे', 'किसी', 'द्वीप', 'पर', 'जाएँ', 'तो', 'सी', 'प्लेन', 'का', 'सफर', 'जरूरी', 'होगा', 'क्योंकि', 'विभिन्न', 'द्वीपों', 'के', 'बीच', 'सफर', 'का', 'यही', 'जरिया', 'है', '।']
# ['And', 'that', 'is', 'one', 'such', 'journey', 'that', 'your', 'heart', 'will', 'never', 'approve', 'of', 'its', 'end', '.']
# ['और', 'वो', 'एक', 'ऐसा', 'सफर', 'होता', 'है', 'जिसके', 'खत्म', 'होने', 'का', 'मन', 'शायद', 'आपका', 'कभी', 'न', 'करे', '।']
# ['Sea', 'plane', 'do', 'journey', 'of', '12', 'kilometres', 'to', '183', 'kilometres', '-LRB-', 'Mavilevaru', 'in', 'north', '-RRB-', 'in', 'the', 'islands', 'of', 'Maldive', '.']
# ['सी', 'प्लेन', '12', 'किलोमीटर', 'से', 'लेकर', '183', 'किलोमीटर', '(', 'उत्तम', 'में', 'मावीलेवारू', ')', 'तक', 'का', 'सफर', 'मालदीव', 'के', 'द्वीपों', 'में', 'करते', 'हैं', '।']
# ['We', 'were', 'in', 'the', 'largest', 'antique', 'and', 'souvenier', 'shop', 'of', 'the', 'capital', 'in', 'Ahmadi', 'market', 'of', 'Malé', '.']
# ['हम', 'माले', 'के', 'अहमदी', 'बाजार', 'में', 'राजधानी', 'की', 'सबसे', 'बड़ी', 'एंटीक', 'व', 'सोवेनियर', 'दुकान', 'में', 'थे', '।']
# ['All', 'salesmen', 'were', 'listening', 'carefully', 'the', 'speech', 'given', 'by', 'president', 'Mohammad', 'Nasheed', 'in', 'World', 'climate', 'conference', 'a', 'day', 'before', 'in', 'Copenhagen', '.']
# ['सारे', 'सेल्समैन', 'मालदीव', 'के', 'राष्\u200dट्रपति', 'मोहम्मद', 'नाशीद', 'द्वारा', 'एक', 'दिन', 'पहले', 'कोपेनहेगन', 'में', 'विश्\u200dव', 'जलवायु', 'सम्मेलन', 'में', 'दिए', 'गए', 'भाषण', 'को', 'बड़े', 'ध्यान', 'से', 'सुन', 'रहे', 'थे', '।']
# ['If', 'I', 'say', 'with', 'honesty', 'then', 'I', 'have', 'never', 'seen', 'any', 'Indian', 'hear', 'speeches', 'of', 'Presidents', 'or', 'Prime', 'ministers', 'so', 'carefully', '.']
# ['ईमानदारी', 'से', 'कहूँ', 'तो', 'मैंने', 'किसी', 'हिंदुस्तानी', 'को', 'राष्\u200dट्रपतियों', 'या', 'प्रधानमंत्री', 'के', 'भाषणों', 'को', 'इतने', 'ध्यान', 'से', 'सुनते', 'नहीं', 'देखा', '।']
# ['But', 'when', 'there', 'is', 'a', 'question', 'of', 'the', 'very', 'existence', 'of', 'a', 'unique', 'creation', 'of', 'earth', 'then', 'this', 'much', 'seriousness', 'was', 'incumbent', 'upon', '.']
# ['लेकिन', 'जब', 'इस', 'धरती', 'की', 'एक', 'नायाब', 'रचना', 'के', 'अस्तित्त्व', 'का', 'ही', 'सवाल', 'हो', 'तो', ',', 'इतनी', 'गंभीरता', 'लाजिमी', 'ही', 'थी', '।']
# ['many', 'people', 'might', 'have', 'considered', 'the', 'meeting', 'held', 'underwater', 'by', 'the', 'cabinet', 'of', 'Maldive', 'a', 'façade', ',', 'but', 'on', 'going', 'to', 'Maldive', 'it', 'feels', 'that', 'if', 'natural', 'calamity', 'snatch', 'it', 'from', 'us', 'then', 'the', 'world', 'will', 'become', 'so', 'poor', '.']
# ['कई', 'लोगों', 'ने', 'अक्टूबर', 'में', 'मालदीव', 'की', 'कैबिनेट', 'द्वारा', 'पानी', 'के', 'अंदर', 'की', 'गई', 'बैठक', 'को', 'भले', 'ही', 'टोटका', 'समझा', 'हो', ',', 'लेकिन', 'मालदीव', 'जाकर', 'लगता', 'है', 'कि', 'अगर', 'प्रकृति', 'का', 'कोप', 'इसे', 'हमसे', 'छीन', 'ले', 'तो', 'दुनिया', 'कितनी', 'दरिद्र', 'हो', 'जाएगी', '।']
# ['Something', 'as', 'special', 'is', 'tehre', 'in', 'the', 'beauty', 'there', '.']
# ['वहाँ', 'की', 'सुंदरता', 'में', 'कुछ', 'ऐसा', 'ही', 'खास', 'है', '।']
# ['As', 'if', 'so', 'much', 'of', 'beauty', 'does', 'not', 'gather', 'in', 'this', 'tiny', 'country', '.']
# ['उस', 'छोटे', 'से', 'देश', 'में', 'मानो', 'इतनी', 'खूबसूरती', 'समाती', 'नहीं', '।']
# ['While', 'returning', 'towards', 'the', 'jetty', 'to', 'go', 'back', 'to', 'cruise', 'after', 'that', 'stroll', 'of', 'market', ',', 'when', 'the', 'gaze', 'suddenly', 'went', 'in', 'the', 'water', 'of', 'ocean', 'moving', 'along', 'side', 'the', 'road', 'then', 'felt', 'that', 'to', 'what', 'extent', 'people', 'here', 'understand', 'the', 'value', 'of', 'beauty', 'here', '.']
# ['बाजार', 'की', 'उस', 'सैर', 'से', 'वापस', 'अपने', 'क्रूज', 'पर', 'जाने', 'के', 'लिए', 'जेट्\u200dटी', 'की', 'तरफ', 'लौटते', 'हुए', ',', 'जब', 'निगाहें', 'बरबस', 'सड़क', 'के', 'साथ-साथ', 'चलते', 'समंदर', 'के', 'पानी', 'में', 'गई', 'तो', 'अहसास', 'हुआ', 'कि', 'यहाँ', 'के', 'लोग', 'इस', 'खूबसूरती', 'की', 'कीमत', 'किस', 'हद', 'तक', 'समझते', 'हैं', '।']
# ['The', 'water', 'was', 'so', 'clear', 'that', 'fishes', 'swimming', 'below', 'in', 'depth', 'of', 'many', 'metres', 'were', 'visible', 'in', 'all', 'their', 'colors', 'in', 'the', 'light', 'of', 'lamp-post', '.']
# ['पानी', 'इतना', 'साफ', 'था', 'कि', 'लैंपपोस्ट', 'की', 'रोशनी', 'में', 'नीचे', 'कई', 'मीटर', 'गहराई', 'में', 'तैरती', 'मछलियाँ', 'अपने', 'सारे', 'रंगों', 'के', 'साथ', 'दिखाई', 'दे', 'रही', 'थीं', '।']
# ['This', 'was', 'that', 'part', 'of', 'the', 'ocean', 'which', 'was', 'right', 'next', 'to', 'the', 'city', '.']
# ['यह', 'समंदर', 'का', 'वो', 'हिस्सा', 'था', 'जो', 'शहर', 'से', 'एकदम', 'सटा', 'हुआ', 'था', '।']
# ['If', 'you', 'are', 'able', 'to', 'see', 'clear', 'even', 'some', 'centimetres', 'in', 'the', 'water', 'of', 'ocean', 'or', 'river', 'abutting', 'to', 'any', 'city', 'of', 'India', 'then', 'will', 'find', 'yourself', 'lucky', '.']
# ['आप', 'भारत', 'के', 'किसी', 'शहर', 'से', 'सटे', 'हुए', 'समुद्र', 'या', 'नदी', 'के', 'पानी', 'में', 'कुछ', 'सेंटीमीटर', 'भी', 'साफ', 'देख', 'सकें', 'तो', 'खुद', 'को', 'खुशकिस्मत', 'पाएँगे', '।']
# ['While', 'returning', 'to', 'MV', 'Aquamarine', 'the', 'two', 'hours', 'of', 'evening', 'spent', 'in', 'Maléy', 'were', 'roaming', 'in', 'our', 'mind', '.']
# ['एमवी', 'एक्वामैरिन', 'पर', 'लौटते', 'हुए', 'माले', 'में', 'बिताए', 'हुए', 'शाम', 'के', 'दो', 'घंटे', 'जेहन', 'में', 'घूम', 'रहे', 'थे', '।']
# ['Coral', 'reef', 'is', 'the', 'life', 'here', '.']
# ['कोरल', 'रीफ', '(', 'मूँगा', 'चट्\u200dटानें', ')', 'यहाँ', 'का', 'जीवन', 'हैं', '।']
# ['To', 'this', 'point', 'that', 'you', 'will', 'find', 'coral', 'even', 'on', 'stones', 'on', 'graves', '.']
# ['यहाँ', 'तक', 'की', 'आपको', 'कब्रों', 'पर', 'लगे', 'पत्थरों', 'पर', 'भी', 'मूँगा', 'चट्\u200dटानें', 'मिल', 'जाएँगी', '।']
# ['A', 'little', 'while', 'before', 'listening', 'to', 'president', 'Nasheed', "'", 's', 'speech', 'we', 'were', 'standing', 'outside', 'his', 'government', 'residence', '.']
# ['राष्\u200dट्रपति', 'नाशीद', 'का', 'भाषण', 'सुनने', 'के', 'कुछ', 'देर', 'पहले', 'हम', 'उनके', 'सरकारी', 'आवास', 'के', 'बाहर', 'खड़े', 'थे', '।']
# ['Could', 'not', 'believe', 'that', 'we', 'were', 'in', 'front', 'of', 'the', 'residence', 'of', 'the', 'supreme', 'persona', 'of', 'a', 'certain', 'country', ',', 'no', 'security', 'guard', 'till', 'far', '.']
# ['यकीन', 'नहीं', 'होता', 'था', 'कि', 'हम', 'किसी', 'देश', 'की', 'सर्वोच्च', 'शख्सियत', 'के', 'आवास', 'के', 'आगे', 'थे', ',', 'दूर-दूर', 'तक', 'कोई', 'सुरक्षाकर्मी', 'नहीं', 'था', '।']
# ['With', 'much', 'pleasure', 'we', 'were', 'clicking', 'photographs', 'by', 'extending', 'our', 'hand', 'from', 'inside', 'the', 'gate', 'of', 'the', 'bungalow', 'at', 'a', 'distance', 'of', 'mere', 'fifty', 'kilometres', '.']
# ['मजे', 'से', 'हम', 'उसके', 'बंगले', 'के', 'दरवाजे', 'से', 'अंदर', 'हाथ', 'बढ़ाकर', 'महज', 'पचास', 'मीटर', 'दूर', 'बगीचे', 'व', 'बरामदे', 'के', 'फोटो', 'खींच', 'रहे', 'थे', '।']
# ['Can', 'you', 'think', 'of', 'this', 'about', 'the', 'house', 'of', 'a', 'petty', 'leader', 'in', 'India', '?']
# ['क्या', 'आप', 'भारत', 'में', 'किसी', 'अदने', 'से', 'नेता', 'के', 'घर', 'के', 'बारे', 'में', 'ऐसा', 'सोच', 'सकते', 'हैं', '?']
# ['Got', 'to', 'know', 'this', 'as', 'well', 'that', 'President', 'at', 'times', 'reaches', 'his', 'office', 'two', 'blocks', 'ahead', 'crossing', 'roads', 'on', 'foot', '.']
# ['पता', 'तो', 'यह', 'भी', 'चला', 'कि', 'राष्\u200dट्रपति', 'कभी', '-', 'कभार', 'पैदल', 'ही', 'सड़कें', 'पार', 'करते', 'हुए', 'दो', 'ब्लॉक', 'आगे', 'अपने', 'दफ्तर', 'में', 'पहुँच', 'जाते', 'हैं', '।']
# ['Every', 'thing', 'about', 'Maldive', 'was', 'overwhelming', '.']
# ['मालदीव', 'के', 'बारे', 'में', 'हर', 'बात', 'अभिभूत', 'करने', 'वाली', 'थी', '।']
# ['This', 'is', 'why', 'I', 'was', 'waiting', 'restlessly', 'for', 'the', 'next', 'day', '.']
# ['इसीलिए', 'मुझे', 'अगले', 'दिन', 'का', 'बेसब्री', 'से', 'इंतजार', 'था', '।']
# ['There', 'was', 'a', 'hunch', 'that', 'the', 'day', 'was', 'going', 'to', 'be', 'special', '.']
# ['इल्हाम', 'था', 'कि', 'वह', 'दिन', 'खास', 'होने', 'वाला', 'था', '।']
# ['In', 'the', 'morning', 'one', 'boat', 'brought', 'us', 'to', 'Airport', 'island', 'from', 'the', 'cruise', '.']
# ['सवेरे', 'क्रूज', 'से', 'एक', 'नाव', 'हमें', 'एयरपोर्ट', 'आईलैंड', 'लेकर', 'आई', '।']
# ['From', 'there', 'while', 'circling', 'around', 'runway', 'we', 'reached', 'on', 'the', 'base', 'of', 'Trans', 'Maldivian', '.']
# ['वहाँ', 'से', 'हम', 'रनवे', 'का', 'चक्कर', 'काटते', 'हुए', 'पहुँचे', 'ट्राँस', 'मालदीवियन', 'के', 'बेस', 'पर', '।']
# ['Last', 'evening', 'when', 'cruise', 'was', 'nearing', 'Malé', 'then', 'we', 'immediately', 'recognized', 'the', 'sea', 'plane', 'passing', 'from', 'above', '.']
# ['पिछली', 'शाम', 'जब', 'क्रूज', 'माले', 'के', 'निकट', 'पहुँच', 'रहा', 'था', 'तो', 'हमने', 'ऊपर', 'से', 'गुजर', 'रहे', 'सी', 'प्लेन', 'को', 'तुरंत', 'पहचान', 'लिया', '।']
# ['We', 'had', 'seen', 'so', 'many', 'pictures', 'of', 'it', '.']
# ['इतनी', 'तस्वीरें', 'जो', 'देखी', 'थी', ',', 'उसकी', '।']
# ['But', 'then', 'there', 'was', 'no', 'likelihood', 'that', 'we', 'would', 'get', 'a', 'chance', 'to', 'ride', 'in', 'it', '.']
# ['लेकिन', 'तब', 'गुमान', 'न', 'था', 'कि', 'अगले', 'दिन', 'उसमें', 'सवारी', 'का', 'मौका', 'मिलेगा', '।']
# ['We', 'were', 'to', 'go', 'to', 'one', 'hundred', 'five', 'kilometres', 'far', 'Rangali', 'island', 'by', 'the', 'sea', 'plane', 'of', 'Trans', 'Maldivian', '.']
# ['ट्रॉस', 'मालदीवियन', 'के', 'सी', 'प्लेन', 'से', 'हम', 'एक', 'सौ', 'पाँच', 'किमी', 'दूर', 'रंगाली', 'द्वीप', 'जाने', 'वाले', 'थे', '।']
# ['To', 'see', 'thousands', 'of', 'resorts', 'and', 'coral', 'islands', 'scattered', 'in', 'sea', 'from', 'the', 'sea', 'plane', 'flying', 'till', 'the', 'height', 'of', 'around', 'thousand', 'metres', 'was', 'unforgettable', '.']
# ['लगभग', 'हजार', 'मीटर', 'की', 'ऊँचाई', 'तक', 'उड़ने', 'वाले', 'सी', 'प्लेन', 'से', 'मालदीव', 'के', 'समुद्र', 'में', 'फैले', 'पड़े', 'सैकड़ों', 'रिजॉर्ट', 'व', 'कोरल', 'द्वीपों', 'को', 'देखना', 'अविस्मरणीय', 'था', '।']
# ['This', 'beauty', 'of', 'water', 'will', 'not', 'be', 'found', 'anywhere', 'else', '.']
# ['पानी', 'की', 'यह', 'खूबसूरती', 'कहीं', 'और', 'नहीं', 'मिलेगी', '।']
# ['That', 'flight', 'was', 'a', 'breathstopping', 'one', 'with', 'thrill', 'and', 'enthusiasm', '.']
# ['रोमांच', 'व', 'उत्साह', 'से', 'साँसें', 'थाम', 'देने', 'वाली', 'उड़ान', 'थी', 'वह', '।']
# ['But', 'on', 'reaching', 'Conrad', 'resorts', 'of', 'Hilton', 'Hotels', 'on', 'Rangali', 'siland', 'it', 'felt', 'as', 'if', 'we', 'reached', 'in', 'some', 'other', 'world', '.']
# ['लेकिन', 'रंगाली', 'द्वीप', 'पर', 'हिल्टन', 'होटल्स', 'के', 'कोनराड', 'रिजॉर्ट', 'पहुँचकर', 'लगा', 'मानो', 'हम', 'किसी', 'दूसरी', 'दुनिया', 'में', 'पहुँच', 'गए', 'हों', '।']
# ['In', 'such', 'a', 'world', 'that', 'had', 'no', 'association', 'with', 'any', 'outside', 'world', '.']
# ['ऐसी', 'दुनिया', 'में', ',', 'जिसका', 'बाहर', 'की', 'किसी', 'दुनिया', 'से', 'कोई', 'वास्ता', 'नहीं', 'था', '।']
# ['Association', 'was', 'also', 'not', 'such', 'that', 'finding', 'something', 'with', 'beauty', 'or', 'luxury', 'like', 'that', 'would', 'be', 'difficult', 'outside', '.']
# ['वास्ता', 'इस', 'तरह', 'भी', 'नहीं', 'था', 'कि', 'वहाँ', 'जैसी', 'खूबसूरती', 'या', 'विलासिता', 'बाहर', 'मिलना', 'मुश्\u200dकिल', 'था', '।']
# ['Sauntering', 'on', 'Conrad', 'road', 'can', 'be', 'done', 'on', 'foot', 'as', 'well', 'as', 'through', 'battery', 'operated', 'car', '.']
# ['कोनराड', 'पर', 'सैर', 'पैदल', 'भी', 'हो', 'सकती', 'है', 'या', 'बैटरी', 'चालित', 'गाड़ी', 'से', 'भी', '।']
# ['While', 'going', 'on', 'to', 'the', 'main', 'island', 'from', 'Jetty', 'the', 'scene', 'of', 'life', 'on', 'both', 'the', 'sides', 'of', 'bridge', 'was', 'marvellous', '.']
# ['जेट्\u200dटी', 'से', 'मुख्य', 'द्वीप', 'तक', 'जाते', 'हुए', 'पुल', 'के', 'दोनों', 'ओर', 'जलजीवन', 'का', 'नजारा', 'अद्\u200dभुत', 'था', '।']
# ['We', 'had', 'not', 'even', 'been', 'able', 'to', 'make', 'oursleves', 'easy', 'with', 'the', 'nature', 'around', ',', 'that', 'we', 'reached', 'such', 'place', ',', 'was', 'unimaginable', '.']
# ['अभी', 'हम', 'आस-पास', 'की', 'प्रकृति', 'से', 'खुद', 'को', 'सहज', 'भी', 'नहीं', 'कर', 'पाए', 'थे', ',', 'कि', 'ऐसी', 'जगह', 'पहुँच', 'गए', ',', 'अकल्पनीय', 'थी', '।']
# ['While', 'descending', 'down', 'in', 'sea', 'water', 'through', 'stairs', 'many', 'metres', 'below', 'we', 'reached', 'in', 'such', 'a', 'room', 'of', 'glass', 'water', 'which', 'was', 'inside', 'water', '.']
# ['सीढ़ियों', 'से', 'कई', 'मीटर', 'नीचे', 'समुद्र', 'के', 'पानी', 'में', 'उतरते', 'हुए', 'हम', 'शीशे', 'के', 'ऐसे', 'कमरे', 'में', 'पहुँच', 'गए', 'जो', 'पानी', 'के', 'अंदर', 'था', '।']
# ['This', 'room', 'was', 'actually', 'a', 'dining', 'room', '.']
# ['वह', 'कमरा', 'दरअसल', 'एक', 'डाइनिंग', 'रूम', 'था', '।']
# ['All', 'around', 'across', 'glass', 'we', 'could', 'see', 'remarkable', 'kind', 'of', 'small', 'and', 'big', 'fishes', ',', 'corals', ',', 'humans', 'doing', 'snorkelling', 'and', 'scuba', 'diving', '.']
# ['सब', 'तरफ', 'शीशों', 'के', 'पार', 'हम', 'विलक्षण', 'किस्म', 'की', 'छोटी', '-', 'बड़ी', 'मछलियाँ', ',', 'कोरल्स', ',', 'स्नोर्कलिंग', 'व', 'स्कूबा', 'डाइविंग', 'करते', 'हुए', 'इंसान', 'देख', 'सकते', 'थे', '।']
# ['The', 'imagination', 'of', 'eating', 'food', 'sitting', 'on', 'decorated', 'tables', 'there', 'was', 'thrilling', 'in', 'itself', '.']
# ['वहाँ', 'सजी', 'मेजों', 'पर', 'बैठकर', 'खाने', 'की', 'कल्पना', 'ही', 'अपने', 'आप', 'में', 'बेहद', 'रोमांचित', 'कर', 'देने', 'वाली', 'थी', '।']
# ['The', 'fare', 'on', 'coming', 'to', 'this', 'island', 'in', 'this', 'sea', 'plane', 'from', 'Maléon', ',', 'on', 'seeing', 'it', 'and', 'having', 'lunch', 'underwater', 'is', '47', 'thousand', 'rupees', 'for', 'one', 'person', '.']
# ['माले', 'से', 'सी', 'प्लेन', 'में', 'इस', 'द्वीप', 'पर', 'आकर', 'इसे', 'देखने', 'और', 'अंडरवाटर', 'लंच', 'करने', 'का', 'किराया', 'ही', 'एक', 'आदमी', 'के', 'लिए', '47', 'हजार', 'रुपये', 'है', '।']
# ['there', 'was', 'no', 'wish', 'to', 'return', 'from', 'there', '.']
# ['वहाँ', 'से', 'लौटने', 'का', 'मन', 'न', 'था', '।']
# ['We', 'were', 'ready', 'to', 'float', 'our', 'passports', 'in', 'water', '.']
# ['हम', 'लोग', 'अपने', 'पासपोर्ट', 'पानी', 'में', 'बहा', 'देने', 'को', 'तैयार', 'थे', '।']
# ['But', 'knew', 'it', 'was', 'not', 'possible', '.']
# ['लेकिन', 'जानते', 'थे', ',', 'यह', 'मुमकिन', 'नहीं', 'था', '।']
# ['With', 'heavy', 'heart', 'we', 'returned', 'with', 'this', 'hope', 'that', 'at', 'some', 'time', 'at', 'some', 'turn', 'fortune', 'will', 'bring', 'us', 'here', 'again', 'for', 'sure', '.']
# ['भारी', 'मन', 'से', 'इसी', 'उम्मीद', 'के', 'साथ', 'लौट', 'पड़े', 'कि', 'फिर', 'कभी', ',', 'किसी', 'मोड़', 'पर', 'तकदीर', 'यहाँ', 'जरूर', 'ले', 'आएगी', '।']
# ['Were', 'making', 'a', 'plan', 'to', 'go', 'out', 'of', 'Delhi', 'since', 'many', 'days', 'but', 'due', 'to', 'the', 'busy', 'work', 'schedule', 'this', 'was', 'not', 'being', 'possible', '.']
# ['कई', 'दिनों', 'से', 'दिल्ली', 'से', 'बाहर', 'जाने', 'की', 'योजना', 'बना', 'रहे', 'थे', 'लेकिन', 'काम', 'की', 'व्यस्तता', 'के', 'चलते', 'यह', 'संभव', 'नहीं', 'हो', 'पा', 'रहा', 'था', '।']
# ['Since', 'childhood', 'had', 'an', 'inclination', 'towards', 'wildlife', 'so', 'thought', 'that', 'why', 'not', 'this', 'time', 'Jim', 'Corbett', 'be', 'visited', '.']
# ['बचपन', 'से', 'वाइल्ड', 'लाइफ', 'का', 'शौक', 'था', 'तो', 'सोचा', 'कि', 'क्यों', 'न', 'इस', 'बार', 'जिम', 'कार्बेट', 'जाया', 'जाए', '।']
# ['After', 'biking', 'till', 'Pegong', 'lake', 'ahead', 'of', 'Khardungla', 'pass', 'in', 'Ladakh', 'in', '2006', 'this', 'was', 'second', 'bike', 'tour', '.']
# ['2006', 'में', 'लद्दाख', 'में', 'खारदूंगला', 'पास', 'से', 'आगे', 'पेगोंग', 'लेक', 'तक', 'की', 'बाइकिंग', 'के', 'बाद', 'यह', 'दूसरा', 'बाइक', 'टूर', 'था', '।']
# ['On', 'the', 'morning', 'of', '27', 'September', 'we', 'set', 'out', 'for', 'Jim', 'Corbett', 'from', 'Delhi', 'but', 'the', 'enthusiasm', 'with', 'which', 'we', 'set', 'out', 'fog', 'had', 'scudded', 'out', 'our', 'speed', '.']
# ['27', 'दिसंबर', 'की', 'तड़के', 'हम', 'दिल्ली', 'से', 'जिम', 'कार्बेट', 'के', 'लिए', 'रवाना', 'हुए', ',', 'लेकिन', 'जिस', 'जोशखरोश', 'से', 'निकले', 'थे', 'कोहरे', 'ने', 'हमारी', 'रफ्तार', 'रफूचक्कर', 'कर', 'दी', '।']
# ['The', 'journey', 'between', 'Hapud', 'to', 'Gajraula', 'was', 'really', 'tiresome', '.']
# ['हापुड़', 'से', 'गजरौला', 'के', 'बीच', 'का', 'सफर', 'वाकई', 'थकाऊ', 'था', '।']
# ['On', 'top', 'of', 'this', 'fog', 'and', 'broken', 'road', 'ahead', '.']
# ['ऊपर', 'से', 'कोहरा', 'और', 'सामने', 'खराब', 'सड़क', '।']
# ['Many', 'a', 'time', 'it', 'felt', 'that', 'now', 'we', 'will', 'fall', '.']
# ['कई', 'बार', 'तो', 'लगा', 'कि', 'अब', 'गिरे', '।']
# ['Somehow', 'reached', 'Gajraula', 'at', '8', 'in', 'the', 'morning', '.']
# ['किसी', 'तरह', 'सुबह', '8', 'बजे', 'गजरौला', 'पहुँचे', '।']
# ['Anyway', 'we', 'reached', 'Ramnagar', 'at', '12', '.']
# ['खैर', 'हम', '12', 'बजे', 'रामनगर', 'पहुँच', 'गए', '।']
# ['Corbett', 'park', 'is', '20', 'kilometres', 'ahead', 'of', 'Ramnagar', '.']
# ['कार्बेट', 'पार्क', 'रामनगर', 'से', '20', 'किलोमीटर', 'आगे', 'है', '।']
# ['Our', 'resort', 'was', 'in', 'Dhikuli', 'near', 'park', 'booking', 'of', 'which', 'we', 'had', 'got', 'done', 'before', 'only', '.']
# ['हमारा', 'रिजॉर्ट', 'पार्क', 'के', 'नजदीक', 'ढिकुली', 'में', 'था', ',', 'जिसकी', 'बुकिंग', 'हमने', 'पहले', 'ही', 'करवा', 'दी', 'थी', '।']
# ['That', 'day', 'there', 'was', 'no', 'special', 'program', 'despite', 'cold', 'we', 'first', 'went', 'to', 'roam', 'on', 'the', 'bank', 'of', 'Kosi', '.']
# ['उस', 'दिन', 'कुछ', 'खास', 'कार्यक्रम', 'था', 'नहीं', 'हम', 'ठंड', 'होने', 'के', 'बावजूद', 'पहले', 'कोसी', 'के', 'किनारे', 'घूमने', 'गए', '।']
# ['After', 'spending', 'two', '-', 'three', 'hours', 'we', 'set', 'out', 'for', 'Corbett', 'museum', 'which', 'was', 'near', 'Dhangdi', 'gate', 'hardly', '2', 'kilometres', 'away', '.']
# ['दो', '-', 'तीन', 'घंटे', 'वहाँ', 'बिताने', 'के', 'बाद', 'हम', 'कार्बेट', 'म्यूजियम', 'निकल', 'गए', ',', 'जो', 'बड़ी', 'मुश्\u200dकिल', '2', 'किमी', 'दूर', 'धांगड़ी', 'गेट', 'के', 'नजदीक', 'था', '।']
# ['From', 'there', 'we', 'went', 'to', 'see', 'Ramnagar', 'down', '.']
# ['वहाँ', 'से', 'हम', 'नीचे', 'रामनगर', 'घूमने', 'चले', 'गए', '।']
# ['While', 'returning', 'it', 'became', 'late', 'evening', '.']
# ['लौटते', 'देर', 'शाम', 'हो', 'गई', '।']
# ['I', 'had', 'left', 'delhi', 'after', 'avowing', 'that', 'I', 'will', 'see', 'a', 'free', 'roaming', 'lion', 'in', 'forest', 'for', 'sure', 'then', 'entire', 'night', 'in', 'dreams', 'lions', 'continued', 'to', 'be', 'seen', 'in', 'dreams', '.']
# ['दिल्ली', 'से', 'ठान', 'कर', 'निकला', 'था', 'कि', 'जंगल', 'में', 'छुट्\u200dटा', 'घूमता', 'शेर', 'जरूर', 'देखूँगा', 'तो', 'पूरी', 'रात', 'सपने', 'में', 'मुझे', 'शेर', 'दिखाई', 'देते', 'रहे', '।']
# ['In', 'the', 'middle', 'of', 'the', 'depth', 'of', 'night', 'a', 'strong', 'roar', 'was', 'heard', 'by', 'me', 'and', 'after', 'that', 'dogs', 'began', 'to', 'bark', 'so', 'loudly', 'that', 'till', 'two', 'hours', 'they', 'did', "n't", 'stop', '.']
# ['रात', 'की', 'गहराइयों', 'के', 'बीच', 'अचानक', 'मुझे', 'जबरदस्त', 'दहाड़', 'सुनाई', 'दी', 'और', 'उसके', 'बाद', 'तो', 'जो', 'कुत्तों', 'ने', 'भौंकना', 'शुरू', 'किया', 'तो', 'दो', 'घंटे', 'तक', 'थमे', 'नहीं', '।']
# ['Therefore', 'came', 'the', 'advice', 'to', 'visit', 'first', 'Kaladhungi', 'and', 'Corbett', 'fall', '.']
# ['लिहाजा', 'पहले', 'कालाढुंगी', 'और', 'कार्बेट', 'फॉल', 'घूमने', 'का', 'सुझाव', 'आया', '।']
# ['Kaladhungi', 'is', 'thirty', 'kilometres', 'far', 'whereas', 'Corbetts', 'lie', 'on', 'the', 'way', 'of', 'fall', '.']
# ['कालाढुंगी', 'तीस', 'किमी', 'दूर', 'है', ',', 'जबकि', 'कार्बेट', 'फॉल', 'रास्ते', 'में', 'पड़ता', 'है', '।']
# ['In', 'Kaladhungi', 'there', 'is', 'museum', 'of', 'Jim', 'Corbett', 'Sahib', 'where', 'some', 'important', 'things', 'related', 'to', 'his', 'private', 'life', 'are', 'kept', '.']
# ['कालाढुंगी', 'में', 'जिम', 'कार्बेट', 'साहब', 'का', 'म्यूजियम', 'है', ',', 'जहाँ', 'उनकी', 'निजी', 'जिंदगी', 'से', 'जुड़ी', 'कुछ', 'अहम', 'चीजें', 'रखी', 'हैं', '।']
# ['It', 'struck', 'half', 'past', 'twelve', 'while', 'returning', 'back', '.']
# ['लौटते-लौटते', 'साढ़े', 'बारह', 'बज', 'गए', '।']
# ['Kaladhungi', 'is', 'an', 'extremely', 'beautiful', 'place', ',', 'Jim', 'Corbett', 'settled', 'in', 'this', 'place', 'only', '.']
# ['कालाढुंगी', 'बेहद', 'खूबसूरत', 'जगह', 'है', ',', 'जिम', 'कार्बेट', 'इसी', 'गाँब', 'में', 'आकर', 'बसे', 'थे', '।']
# ['On', 'reaching', 'Resort', 'safari', 'gypsy', 'was', 'waiting', 'for', 'us', '.']
# ['रिजॉर्ट', 'पहुँचने', 'पर', 'सफारी', 'जिप्सी', 'हमारा', 'इंतजार', 'कर', 'रही', 'थी', '।']
# ['It', 'was', 'told', 'that', 'facility', 'of', 'siting', 'was', 'done', 'in', 'number', 'one', 'site', 'Bijraani', 'there', '.']
# ['बताया', 'गया', 'कि', 'उन्होंने', 'वहाँ', 'की', 'नंबर', 'एक', 'साइट', 'बिजरानी', 'में', 'साइटिंग', 'की', 'व्यवस्था', 'कराई', 'है', '।']
# ['On', 'asking', 'about', 'number', 'one', 'we', 'were', 'told', 'that', 'grassland', 'are', 'more', 'there', 'and', 'during', 'this', 'time', 'tiger', 'come', 'that', 'side', 'only', 'to', 'escape', 'from', 'cold', '.']
# ['नंबर', 'एक', 'के', 'बारे', 'में', 'पूछने', 'पर', 'बताया', 'कि', 'वहाँ', 'ग्रासलैंड', 'ज्यादा', 'है', 'और', 'टाइगर', 'इस', 'दौरान', 'ठंड', 'से', 'बचने', 'के', 'लिए', 'उसी', 'तरफ', 'आते', 'हैं', '।']
# ['We', 'were', 'given', 'a', 'guide', 'on', 'reaching', 'Bijrani', 'who', 'takes', 'Rs', '.', '250', 'for', 'making', 'us', 'roam', '.']
# ['बिजरानी', 'पहुँचते', 'ही', 'हमें', 'एक', 'गाइड', 'दिया', 'गया', ',', 'जो', 'चार', 'घंटे', 'घुमाने', 'के', 'ढाई', 'सौ', 'रुपये', 'लेता', 'है', '।']
# ['We', 'set', 'out', 'for', 'forest', 'inside', '.']
# ['हम', 'अंदर', 'जंगल', 'के', 'लिए', 'रवाना', 'हो', 'गए', '।']
# ['There', 'we', 'saw', 'animals', 'of', 'various', 'kinds', 'and', 'many', 'species', 'of', 'deers', '.']
# ['हमने', 'वहाँ', 'कई', 'तरह', 'के', 'जानवर', 'और', 'हिरनों', 'की', 'कई', 'प्रजातियाँ', 'देखीं', '।']
# ['We', 'saw', 'two', 'tusker', 'elephants', 'inside', 'who', 'had', 'very', 'long', 'tusks', '.']
# ['अंदर', 'हमने', 'दो', 'टस्कर', 'हाथी', 'देखे', ',', 'जिनके', 'लंबे-लंबे', 'दाँत', 'थे', '।']
# ['I', 'photographed', 'profusely', '.']
# ['मैंने', 'जमकर', 'फोटोग्राफी', 'की', '।']
# ['Amidst', 'all', 'this', 'the', 'guide', 'began', 'to', 'track', 'tiger', '.']
# ['इस', 'बीच', 'गाइड', 'ने', 'टाइगर', 'को', 'ट्रैक', 'करना', 'शुरू', 'कर', 'दिया', '।']
# ['Guide', 'told', 'us', 'that', 'there', 'are', 'only', 'around', '150', 'tigers', 'in', 'the', 'park', ',', 'of', 'them', 'some', 'have', 'died', 'lately', '.']
# ['गाइड', 'ने', 'बताया', 'कि', 'पार्क', 'में', 'तकरीबन', '150', 'के', 'आस-पास', 'ही', 'टाइगर', 'हैं', ',', 'जिनमें', 'से', 'हाल', 'ही', 'में', 'कुछ', 'मर', 'चुके', 'हैं', '।']
# ['At', 'many', 'places', 'we', 'saw', 'their', 'paw', 'prints', 'but', 'I', 'was', 'upset', 'for', 'not', 'being', 'able', 'to', 'find', 'the', 'sight', 'of', 'tiger', '.']
# ['कई', 'जगह', 'हमें', 'उनके', 'पंजों', 'के', 'निशान', 'भी', 'दिखे', ',', 'लेकिन', 'टाइगर', 'का', 'दर्शन', 'न', 'मिलने', 'से', 'मैं', 'उदास', 'था', '।']
# ['Third', 'day', 'we', 'had', 'to', 'return', 'to', 'Delhi', '.']
# ['तीसरे', 'दिन', 'हमें', 'दिल्ली', 'लौटना', 'था', '।']
# ['In', 'my', 'brain', 'the', 'furor', 'of', 'tiger', 'was', 'running', 'heavy', '.']
# ['मेरे', 'दिमाग', 'में', 'तो', 'टाइगर', 'का', 'फितूर', 'सवार', 'था', '।']
# ['Suddenly', 'then', 'I', 'remebered', 'an', 'old', 'friend', 'of', 'mine', 'of', 'Haldwani', '.']
# ['तभी', 'मुझे', 'हल्द्वानी', 'के', 'अपने', 'एक', 'पुराने', 'मित्र', 'की', 'याद', 'आई', '।']
# ['I', 'called', 'him', 'just', 'like', 'that', 'only', '.']
# ['मैंने', 'उसे', 'ऐसे', 'ही', 'फोन', 'लगा', 'दिया', '।']
# ['I', 'told', 'him', 'that', 'I', 'have', 'come', 'to', 'Corbett', '.']
# ['मैंने', 'उसे', 'बताया', 'कि', 'मैं', 'कार्बेट', 'आया', 'हुआ', 'हूँ', '।']
# ['He', 'asked', 'you', 'saw', 'tiger', 'or', 'not', '.']
# ['उसने', 'पूछा', 'टाइगर', 'देखा', 'या', 'नहीं', '।']
# ['These', 'words', 'pricked', 'like', 'an', 'arrow', '.']
# ['उसके', 'यह', 'शब्द', 'तीर', 'की', 'तरह', 'चुभ', 'गए', '।']
# ['I', 'slowly', 'said', 'no', '.']
# ['मैंने', 'धीरे', 'से', 'कहा', ',', 'नहीं', '।']
# ['There', 'was', 'no', 'permission', 'to', 'take', 'bike', 'inside', 'the', 'park', '.']
# ['पार्क', 'में', 'बाइक', 'ले', 'जाने', 'की', 'अनुमति', 'नहीं', 'थी', '।']
# ['Somebody', 'advised', 'us', 'that', 'we', 'should', 'take', 'safari', 'for', 'inside', '.']
# ['हमें', 'किसी', 'ने', 'सलाह', 'दी', 'कि', 'आप', 'अंदर', 'के', 'लिए', 'सफारी', 'ले', 'लो', '।']
